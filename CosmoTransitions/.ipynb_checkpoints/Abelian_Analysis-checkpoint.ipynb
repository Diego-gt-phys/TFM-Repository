# %%
import numpy as np

import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
import matplotlib.lines as mlines
from matplotlib.cm import ScalarMappable
from matplotlib.colors import Normalize
from matplotlib.gridspec import GridSpec

from scipy.optimize import minimize_scalar

from AbelianCT_Potential import Abelian_Model as AbelianCT_Model
from AbelianCT_Potential import Abelian_Model

# %% [markdown]
# ## Define the Model

# %%
# Parameters: strong FOPT regime (large g/sqrt(lam) ratio)
lam, mu, g = 0.05, 50.0, 1

model = AbelianCT_Model(lam, mu, g)

# Analytic expectations
v_tree  = mu / np.sqrt(lam)
mh_tree = np.sqrt(2.0) * mu
mA_tree = g * v_tree
print(f"Tree-level vev :  v  = {v_tree:.3f} GeV")
print(f"Tree-level Higgs: mh = {mh_tree:.3f} GeV")
print(f"Tree-level gauge: mA = {mA_tree:.3f} GeV")

# Numerical vev from Vtot(T=0)
T_eps = 1e-6  # numerically zero, avoids division by T=0

res = minimize_scalar(
    lambda phi: model.Vtot(np.array([[phi]]), T_eps).item(),
    bounds=(50, 350),
    method='bounded'
)
v_num = res.x
print(f"Numerical vev (Vtot, T=0): {v_num:.3f} GeV")
print(f"CW shift: {abs(v_num - v_tree)/v_tree * 100:.3f}%")
# Out:
# Tree-level vev :  v  = 223.607 GeV
# Tree-level Higgs: mh = 70.711 GeV
# Tree-level gauge: mA = 223.607 GeV
# Numerical vev (Vtot, T=0): 223.607 GeV
# CW shift: 0.000%

# %% [markdown]
# ## Coleman Weinberg ($T=0$)

# %%
phi_vals = np.linspace(-500, 500, 1500)
X        = phi_vals[:, np.newaxis] 

V_tree   = model.V0(X)
V_tot_0  = model.Vtot(X, 0.0)

fig, ax = plt.subplots(figsize=(9.7, 6))

ax.axhline(0, color='k', lw=1, ls='-')
ax.axvline(0, color='k', lw=1, ls='-')

ax.plot(phi_vals, V_tot_0-model.Vtot(np.array([[0.0]]), 0.0), label=r'$V_0 + V_\mathrm{CW}$', color='r', lw=1.5, ls='-')
ax.plot(phi_vals, V_tree-model.V0(np.array([[0.0]])), label=r'$V_0$', color='b', lw=1.5, ls='-.')

ax.axvline(v_num, label=rf'$v={float(np.squeeze(v_num)):.0f} \, \mathrm{{GeV}}$', color='gray', lw=1.0, ls='-', alpha=1)
ax.axvline(v_tree, label=rf'$v_0={v_tree:.0f} \, \mathrm{{GeV}}$', color='gray', lw=1.5, ls='-.', alpha=1)

ax.set_xlim(-350, 350)
ax.set_ylim(-3.5e7,2e7)

ax.set_xlabel(r'$\varphi$ $\left[\mathrm{GeV}\right]$', fontsize=18)
ax.set_ylabel(r'$V_\mathrm{eff}\,(\varphi)$ $\left[\mathrm{GeV^4}\right]$', fontsize=18)
ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
ax.ticklabel_format(style='sci', axis='y', scilimits=(-2, 2))
ax.yaxis.get_offset_text().set_fontsize(15)
ax.spines['top'].set_linewidth(1.5)
ax.spines['right'].set_linewidth(1.5)
ax.spines['bottom'].set_linewidth(1.5)
ax.spines['left'].set_linewidth(1.5)

ax.tick_params(axis='both', which='major', direction='in', length=8, width=1.2, labelsize=15, top=True, right=True)
ax.tick_params(axis='both', which='minor', direction='in', length=4, width=1, labelsize=15, top=True, right=True)
ax.minorticks_on()
ax.tick_params(axis='x', which='major', pad=5)

plt.legend(fontsize=18, frameon=True, fancybox=False, loc = "lower center", bbox_to_anchor=(0.5, 0.005),
               ncol = 1, edgecolor="black", framealpha=1, labelspacing=0.2, handletextpad=0.3, handlelength=1, columnspacing=1)

plt.title(r"Coleman-Weinber", loc='left', fontsize=20, fontweight='bold')
plt.tight_layout()
plt.savefig("figures\AbelianCT_CW.pdf", format="pdf", bbox_inches="tight")

plt.show()

# %% [markdown]
# ## Thermal Evolution

# %%
T_vals   = np.array([0, 77, 100, 111, 120, 150, 200])
phi_vals = np.linspace(-1,400,2000)
X        = phi_vals[:, np.newaxis]

# Colormap
cmap  = plt.cm.plasma
norm  = Normalize(vmin=0, vmax=T_vals.max())
sm    = ScalarMappable(cmap=cmap, norm=norm)

fig, ax = plt.subplots(figsize=(9.7, 6))

ax.axhline(0, color='k', lw=1, ls='-')
ax.axvline(0, color='k', lw=1, ls='-')

for T in T_vals:
    V = model.Vtot(X, T)
    V_norm = V - model.Vtot(np.array([[0.0]]), T)
    color = cmap(norm(T))
    label = r'$T = 0$' if T < 1 else rf'$T = {T:.0f}$ GeV'
    ax.plot(phi_vals, V_norm, color=color, lw=1.5, label=label)

    # Mark the minimum of the broken phase
    mask = phi_vals > 0          # Impose Positive vev
    idx  = np.argmin(V[mask])
    phi_min = phi_vals[mask][idx]
    V_min   = V[mask][idx]
    ax.plot(phi_min, V_min-model.Vtot(np.array([[0.0]]), T), 'o', color=color, ms=5)

ax.set_xlim(0, 320)
ax.set_ylim(-3e7,1e7)

ax.set_xlabel(r'$\varphi$ $\left[\mathrm{GeV}\right]$', fontsize=18)
ax.set_ylabel(r'$V_\mathrm{eff}\,(\varphi, T)$ $\left[\mathrm{GeV^4}\right]$', fontsize=18)

ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
ax.ticklabel_format(style='sci', axis='y', scilimits=(-2, 2))
ax.yaxis.get_offset_text().set_fontsize(15)
for spine in ax.spines.values():
    spine.set_linewidth(1.5)

# Configure ticks
ax.tick_params(axis='both', which='major', direction='in', length=8, width=1.2, labelsize=15, top=True, right=True)
ax.tick_params(axis='both', which='minor', direction='in', length=4, width=1, labelsize=15, top=True, right=True)
ax.minorticks_on()

cbar = fig.colorbar(sm, ax=ax, pad=0.01)
cbar.set_label(r'$T\ [\mathrm{GeV}]$', fontsize=18)
cbar.ax.tick_params(labelsize=15)


annotation = (rf"$T_c   = 111.01 \, \mathrm{{GeV}}$"  "\n"rf"$\xi_c = 1.58$")
ax.text(0.05, 0.18, annotation,transform=ax.transAxes,fontsize=18,verticalalignment='top',horizontalalignment='left')

plt.title(r"Thermal Evolution", loc='left', fontsize=20, fontweight='bold')
plt.tight_layout()
plt.savefig("figures\AbelianCT_Thermal.pdf", format="pdf", bbox_inches="tight")

plt.show()

# %% [markdown]
# ## Phase Transition

# %%
model.Tmax = 200

# %% [markdown]
# ### Critical Temperature $T_C$

# %%
trans = model.calcTcTrans()
Tc   = trans[0]['Tcrit']
high = trans[0]['high_vev']
low  = trans[0]['low_vev']
xi_c = abs(low[0] - high[0]) / Tc
print(f"Tc = {Tc:.2f} GeV  |  xi_c = {xi_c:.2f}")
# Out:
# Tracing phase starting at x = [223.60679787] ; t = 0.0
# Tracing minimum up
# traceMinimum t0 = 0
# ..........................................................................................................................................
# Tracing phase starting at x = [-3.11523438e-06] ; t = 116.85762646791667
# Tracing minimum down
# traceMinimum t0 = 116.858
# ...............................
# Tracing minimum up
# traceMinimum t0 = 116.858
# ....
# Tc = 111.01 GeV  |  xi_c = 1.58

# %%
model.getPhases()
# Out:
# Tracing phase starting at x = [223.60679787] ; t = 0.0
# Tracing minimum up
# traceMinimum t0 = 0
# ..........................................................................................................................................
# Tracing phase starting at x = [-3.11523438e-06] ; t = 116.85762646791667
# Tracing minimum down
# traceMinimum t0 = 116.858
# ...............................
# Tracing minimum up
# traceMinimum t0 = 116.858
# ....
# {0: Phase(key=0, X=[[223.6], ..., [138.9]], T=[0, ..., 116.7], dXdT=[[-0], ..., [-71.64]],
#  1: Phase(key=1, X=[[0.00332], ..., [0.0006843]], T=[83.71, ..., 200], dXdT=[[-10.13], ..., [-1.591e-05]]}

# %%
model.getPhases()
for k, phase in model.phases.items():
    print(f"Phase {k}: T range [{phase.T[0]:.2f}, {phase.T[-1]:.2f}], "
          f"field value at Tmin = {phase.X[0]}")
# Out:
# Tracing phase starting at x = [223.60679787] ; t = 0.0
# Tracing minimum up
# traceMinimum t0 = 0
# ..........................................................................................................................................
# Tracing phase starting at x = [-3.11523438e-06] ; t = 116.85762646791667
# Tracing minimum down
# traceMinimum t0 = 116.858
# ...............................
# Tracing minimum up
# traceMinimum t0 = 116.858
# ....
# Phase 0: T range [0.00, 116.66], field value at Tmin = [223.60679787]
# Phase 1: T range [83.71, 200.00], field value at Tmin = [0.00331977]

# %%
from cosmoTransitions import pathDeformation, transitionFinder
import numpy as np

Tc = model.TcTrans[0]['Tcrit']
T_test = 0.933 * Tc  # well below Tc, should be clean

# Get the two phase field values at this T
x0 = model.TcTrans[0]['high_vev']   # false vacuum (symmetric)
#x0 = np.array([0.0])   # force it
x1 = model.TcTrans[0]['low_vev']  # true vacuum (broken)

print("False vac:", x0)
print("True vac: ", x1)

# Build the T-fixed potential
V_  = lambda x: model.Vtot(x, T_test)
dV_ = lambda x: model.gradV(x, T_test)

print("V(false):", V_(x0))
print("V(true): ", V_(x1))
print("Delta V: ", V_(x0) - V_(x1))  # must be positive for FOPT
# Out:
# False vac: [0.0028279]
# True vac:  [175.34883855]
# V(false): -62903663.2851359
# V(true):  -66481305.617210485
# Delta V:  3577642.3320745826

# %%
tobj = pathDeformation.fullTunneling(
    [x1, x0], V_, dV_,
    callback_data=T_test,
    verbose=True
)
print("Action:", tobj.action)
print("S3/T:  ", tobj.action / T_test)
# Out:
# Starting tunneling step 1
# Path deformation converged. 1 steps. fRatio = 9.63604e-14
# Action: 14496.988280378728
# S3/T:   139.9712429890008

# %%
from cosmoTransitions import pathDeformation
from scipy.interpolate import interp1d
import numpy as np

# Rebuild phases in case findAllTransitions corrupted them
model.getPhases()
model.calcTcTrans()

Tc = model.TcTrans[0]['Tcrit']

# Extract the broken-phase trajectory and build an interpolator
high_key = model.TcTrans[0]['high_phase']
phase_obj = model.phases[high_key]

# phase_obj.X has shape (n_T_points, n_fields), phase_obj.T has shape (n_T_points,)
x1_interp = interp1d(phase_obj.T, phase_obj.X, axis=0, 
                      bounds_error=False, fill_value='extrapolate')

x0_fixed = np.array([0.0])

T_vals = np.linspace(0.80*Tc, 0.999*Tc, 30)

for T in T_vals:
    x1_T = x1_interp(T)
    V_  = lambda x: model.Vtot(x, T)
    dV_ = lambda x: model.gradV(x, T)
    try:
        tobj = pathDeformation.fullTunneling(
            [x1_T, x0_fixed], V_, dV_,
            callback_data=T
        )
        s3t = tobj.action / T
    except Exception as e:
        s3t = np.nan
        print(f"  -> failed: {e}")
    print(f"T={T:.3f}  S3/T={s3t:.3f}")
# Out:
# Tracing phase starting at x = [223.60679787] ; t = 0.0
# Tracing minimum up
# traceMinimum t0 = 0
# ..........................................................................................................................................
# Tracing phase starting at x = [-3.11523438e-06] ; t = 116.85762646791667
# Tracing minimum down
# traceMinimum t0 = 116.858
# ...............................
# Tracing minimum up
# traceMinimum t0 = 116.858
# ....
#   -> failed: ('V(phi_metaMin) <= V(phi_absMin); tunneling cannot occur.', 'stable, not metastable')
# T=88.807  S3/T=nan
#   -> failed: ('V(phi_metaMin) <= V(phi_absMin); tunneling cannot occur.', 'stable, not metastable')
# T=89.569  S3/T=nan
#   -> failed: ('V(phi_metaMin) <= V(phi_absMin); tunneling cannot occur.', 'stable, not metastable')
# T=90.331  S3/T=nan
#   -> failed: ('V(phi_metaMin) <= V(phi_absMin); tunneling cannot occur.', 'stable, not metastable')
# T=91.092  S3/T=nan
#   -> failed: ('V(phi_metaMin) <= V(phi_absMin); tunneling cannot occur.', 'stable, not metastable')
# T=91.854  S3/T=nan
#   -> failed: ('V(phi_metaMin) <= V(phi_absMin); tunneling cannot occur.', 'stable, not metastable')
# T=92.616  S3/T=nan
#   -> failed: ('V(phi_metaMin) <= V(phi_absMin); tunneling cannot occur.', 'stable, not metastable')
# T=93.378  S3/T=nan
#   -> failed: ('V(phi_metaMin) <= V(phi_absMin); tunneling cannot occur.', 'stable, not metastable')
# T=94.139  S3/T=nan
#   -> failed: ('V(phi_metaMin) <= V(phi_absMin); tunneling cannot occur.', 'stable, not metastable')
# T=94.901  S3/T=nan
#   -> failed: ('V(phi_metaMin) <= V(phi_absMin); tunneling cannot occur.', 'stable, not metastable')
# T=95.663  S3/T=nan
#   -> failed: ('V(phi_metaMin) <= V(phi_absMin); tunneling cannot occur.', 'stable, not metastable')
# T=96.425  S3/T=nan
#   -> failed: ('V(phi_metaMin) <= V(phi_absMin); tunneling cannot occur.', 'stable, not metastable')
# T=97.186  S3/T=nan
#   -> failed: ('V(phi_metaMin) <= V(phi_absMin); tunneling cannot occur.', 'stable, not metastable')
# T=97.948  S3/T=nan
#   -> failed: ('V(phi_metaMin) <= V(phi_absMin); tunneling cannot occur.', 'stable, not metastable')
# T=98.710  S3/T=nan
#   -> failed: ('V(phi_metaMin) <= V(phi_absMin); tunneling cannot occur.', 'stable, not metastable')
# T=99.472  S3/T=nan
#   -> failed: ('V(phi_metaMin) <= V(phi_absMin); tunneling cannot occur.', 'stable, not metastable')
# T=100.233  S3/T=nan
#   -> failed: ('V(phi_metaMin) <= V(phi_absMin); tunneling cannot occur.', 'stable, not metastable')
# T=100.995  S3/T=nan
#   -> failed: ('V(phi_metaMin) <= V(phi_absMin); tunneling cannot occur.', 'stable, not metastable')
# T=101.757  S3/T=nan
#   -> failed: ('V(phi_metaMin) <= V(phi_absMin); tunneling cannot occur.', 'stable, not metastable')
# T=102.519  S3/T=nan
#   -> failed: ('V(phi_metaMin) <= V(phi_absMin); tunneling cannot occur.', 'stable, not metastable')
# T=103.280  S3/T=nan
#   -> failed: ('V(phi_metaMin) <= V(phi_absMin); tunneling cannot occur.', 'stable, not metastable')
# T=104.042  S3/T=nan
#   -> failed: ('V(phi_metaMin) <= V(phi_absMin); tunneling cannot occur.', 'stable, not metastable')
# T=104.804  S3/T=nan
#   -> failed: ('V(phi_metaMin) <= V(phi_absMin); tunneling cannot occur.', 'stable, not metastable')
# T=105.566  S3/T=nan
#   -> failed: ('V(phi_metaMin) <= V(phi_absMin); tunneling cannot occur.', 'stable, not metastable')
# T=106.327  S3/T=nan
#   -> failed: ('V(phi_metaMin) <= V(phi_absMin); tunneling cannot occur.', 'stable, not metastable')
# T=107.089  S3/T=nan
# Path deformation converged. 1 steps. fRatio = 5.72966e-14
# T=107.851  S3/T=0.000
#   -> failed: ('Barrier height is not positive, does not exist.', 'no barrier')
# T=108.613  S3/T=nan
#   -> failed: ('V(phi_metaMin) <= V(phi_absMin); tunneling cannot occur.', 'stable, not metastable')
# T=109.374  S3/T=nan
#   -> failed: r > rmax
# T=110.136  S3/T=nan
#   -> failed: ('V(phi_metaMin) <= V(phi_absMin); tunneling cannot occur.', 'stable, not metastable')
# T=110.898  S3/T=nan

# %%
from cosmoTransitions import pathDeformation
from scipy.optimize import minimize, brentq
import numpy as np

model.getPhases()
model.calcTcTrans()
Tc = model.TcTrans[0]['Tcrit']
print(f"Tc = {Tc:.4f}")

x0_fixed = np.array([0.0])

def get_broken_vev(T, x_init=None):
    if x_init is None:
        x_init = np.array([246.0])
    V_T = lambda x: model.Vtot(x, T)
    res = minimize(V_T, x_init, method='Nelder-Mead',
                   options={'xatol':1e-8, 'fatol':1e-8})
    return res.x

def compute_S3T(T):
    x1_T = get_broken_vev(T)
    dV = model.Vtot(x0_fixed, T) - model.Vtot(x1_T, T)
    if dV <= 0:
        raise ValueError(f"Phase ordering wrong at T={T:.3f}, dV={dV:.3e}")
    V_  = lambda x: model.Vtot(x, T)
    dV_ = lambda x: model.gradV(x, T)
    tobj = pathDeformation.fullTunneling(
        [x1_T, x0_fixed], V_, dV_, callback_data=T
    )
    return tobj.action / T

# Step 1 — coarse scan to bracket Tn
print("\n--- Coarse scan ---")
T_vals = np.linspace(0.5*Tc, 0.98*Tc, 20)
s3t_vals = []

for T in T_vals:
    try:
        s3t = compute_S3T(T)
    except Exception as e:
        s3t = np.nan
        print(f"T={T:.3f}  FAILED: {e}")
    else:
        print(f"T={T:.3f}  S3/T={s3t:.3f}")
    s3t_vals.append(s3t)

# Step 2 — find bracket where S3/T crosses 140
s3t_arr = np.array(s3t_vals)
# S3/T is large near Tc and small at low T, so we want crossing from below 140 to above
valid = np.isfinite(s3t_arr)
T_valid = T_vals[valid]
s3t_valid = s3t_arr[valid]

# Find index where S3/T crosses 140
cross_idx = np.where(np.diff(np.sign(s3t_valid - 140)))[0]
if len(cross_idx) == 0:
    print("\nNo crossing found — check scan range or nucleation criterion")
else:
    T_lo = T_valid[cross_idx[0]]
    T_hi = T_valid[cross_idx[0] + 1]
    print(f"\nBracket found: [{T_lo:.3f}, {T_hi:.3f}]")

    # Step 3 — refine with brentq
    def objective(T):
        try:
            return compute_S3T(T) - 140.0
        except Exception:
            return np.nan

    Tn = brentq(objective, T_lo, T_hi, xtol=0.1, maxiter=20)
    print(f"\n*** Nucleation temperature: Tn = {Tn:.4f} GeV ***")
    print(f"    S3/T at Tn = {compute_S3T(Tn):.3f}")
    print(f"    Tc        = {Tc:.4f} GeV")
    print(f"    Tn/Tc     = {Tn/Tc:.4f}")
    print(f"    strength  = v(Tn)/Tn = {get_broken_vev(Tn)[0]/Tn:.4f}")
# Out:
# Tracing phase starting at x = [223.60679787] ; t = 0.0
# Tracing minimum up
# traceMinimum t0 = 0
# ..........................................................................................................................................
# Tracing phase starting at x = [-3.11523438e-06] ; t = 116.85762646791667
# Tracing minimum down
# traceMinimum t0 = 116.858
# ...............................
# Tracing minimum up
# traceMinimum t0 = 116.858
# ....
# Tc = 111.0088
#
# --- Coarse scan ---
# T=55.504  FAILED: The function value at x=1.9266232842027615e+307 is NaN; solver cannot continue.
# T=58.309  FAILED: The function value at x=1.9484249032648423e+307 is NaN; solver cannot continue.
# T=61.113  FAILED: ('V(phi_metaMin) <= V(phi_absMin); tunneling cannot occur.', 'stable, not metastable')
# T=63.918  FAILED: ('V(phi_metaMin) <= V(phi_absMin); tunneling cannot occur.', 'stable, not metastable')
# T=66.722  FAILED: ('V(phi_metaMin) <= V(phi_absMin); tunneling cannot occur.', 'stable, not metastable')
# T=69.527  FAILED: ('V(phi_metaMin) <= V(phi_absMin); tunneling cannot occur.', 'stable, not metastable')
# T=72.331  FAILED: ('V(phi_metaMin) <= V(phi_absMin); tunneling cannot occur.', 'stable, not metastable')
# T=75.135  FAILED: ('V(phi_metaMin) <= V(phi_absMin); tunneling cannot occur.', 'stable, not metastable')
# C:\Users\Usuario\anaconda3\Lib\site-packages\cosmoTransitions\tunneling1D.py:337: RuntimeWarning: overflow encountered in scalar multiply
#   beta_r = beta*r
# C:\Users\Usuario\anaconda3\Lib\site-packages\cosmoTransitions\tunneling1D.py:421: RuntimeWarning: overflow encountered in scalar multiply
#   r *= 10
# C:\Users\Usuario\anaconda3\Lib\site-packages\cosmoTransitions\tunneling1D.py:337: RuntimeWarning: overflow encountered in scalar multiply
#   beta_r = beta*r
# C:\Users\Usuario\anaconda3\Lib\site-packages\cosmoTransitions\tunneling1D.py:337: RuntimeWarning: overflow encountered in scalar multiply
#   beta_r = beta*r
# C:\Users\Usuario\anaconda3\Lib\site-packages\cosmoTransitions\tunneling1D.py:421: RuntimeWarning: overflow encountered in scalar multiply
#   r *= 10
# C:\Users\Usuario\anaconda3\Lib\site-packages\cosmoTransitions\tunneling1D.py:337: RuntimeWarning: overflow encountered in scalar multiply
#   beta_r = beta*r
# T=77.940  FAILED: ('V(phi_metaMin) <= V(phi_absMin); tunneling cannot occur.', 'stable, not metastable')
# T=80.744  FAILED: ('V(phi_metaMin) <= V(phi_absMin); tunneling cannot occur.', 'stable, not metastable')
# T=83.549  FAILED: ('V(phi_metaMin) <= V(phi_absMin); tunneling cannot occur.', 'stable, not metastable')
# Path deformation converged. 1 steps. fRatio = 7.70859e-14
# T=86.353  S3/T=3.389
# Path deformation converged. 1 steps. fRatio = 5.35789e-14
# T=89.158  S3/T=9.372
# Path deformation converged. 1 steps. fRatio = 3.68479e-14
# T=91.962  S3/T=17.874
# Path deformation converged. 1 steps. fRatio = 2.82456e-14
# T=94.766  S3/T=29.823
# Path deformation converged. 1 steps. fRatio = 7.06553e-14
# T=97.571  S3/T=47.214
# Path deformation converged. 1 steps. fRatio = 8.31493e-14
# T=100.375  S3/T=74.563
# Path deformation converged. 1 steps. fRatio = 5.81213e-14
# T=103.180  S3/T=128.655
# Path deformation converged. 1 steps. fRatio = 9.53901e-14
# T=105.984  S3/T=269.058
# Path deformation converged. 1 steps. fRatio = 1.56778e-13
# T=108.789  S3/T=1094.331
#
# Bracket found: [103.180, 105.984]
# Path deformation converged. 1 steps. fRatio = 5.81213e-14
# Path deformation converged. 1 steps. fRatio = 9.53901e-14
# Path deformation converged. 1 steps. fRatio = 3.86298e-14
# Path deformation converged. 1 steps. fRatio = 5.78063e-14
# Path deformation converged. 1 steps. fRatio = 7.71223e-14
#
# *** Nucleation temperature: Tn = 103.5854 GeV ***
# Path deformation converged. 1 steps. fRatio = 5.78063e-14
#     S3/T at Tn = 140.419
#     Tc        = 111.0088 GeV
#     Tn/Tc     = 0.9331
#     strength  = v(Tn)/Tn = 1.8492
