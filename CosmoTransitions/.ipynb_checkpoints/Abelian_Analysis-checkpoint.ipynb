# %%
import numpy as np
import matplotlib.pyplot as plt
from Abelian_Potential import Abelian_Model

# %% [markdown]
# ## Define The Model

# %%
# Tree-level VEV expected at: v = mu / sqrt(lambda) = 50 / sqrt(0.1) ≈ 158.11 GeV
lam = 0.1
mu = 9
g = 0.4

# Instantiate the model
model = Abelian_Model(lam=lam, mu=mu, g=g)

print("Model successfully initialized!")
print(f"Expected tree-level VEV: {mu / np.sqrt(lam):.2f} GeV")
# Out:
# Model successfully initialized!
# Expected tree-level VEV: 28.46 GeV

# %%
# 1. Find the true quantum vacuum minimum at T=0
guess_true_vacuum = np.array([28.46])
vac_true = model.findMinimum(guess_true_vacuum, T=0)

# 2. Evaluate the false vacuum directly at the origin (phi = 0)
# We pass [0.0] as a coordinate array directly to Vtot
vac_false = np.array([0.0])

print(f"True quantum vacuum minimum at T=0:  phi = {vac_true[0]:.4f} GeV")
print(f"False vacuum minimum at T=0:         phi = {vac_false[0]:.4f} GeV")

# 3. Check the potential depth
V_true = model.Vtot(vac_true, T=0)
V_false = model.Vtot(vac_false, T=0)
print(f"Potential energy density difference (ΔV): {V_false - V_true:.4f} GeV^4")
# Out:
# True quantum vacuum minimum at T=0:  phi = 29.3287 GeV
# False vacuum minimum at T=0:         phi = 0.0000 GeV
# Potential energy density difference (ΔV): 17157.8515 GeV^4

# %%
print("Running phase tracking loops...")

# Call findAllTransitions directly from your model instance
transitions = model.findAllTransitions()

print("\n--- Phase Transition Analysis Complete ---")
if not transitions or len(transitions) == 0:
    print("No phase transitions found for this parameter set.")
else:
    for i, trans in enumerate(transitions):
        print(f"\nTransition #{i+1}:")
        
        # 'trantype' handles Step 4 (Phase Tracking type identification)
        t_type = "1st Order" if trans['trantype'] == 1 else "2nd Order"
        print(f"  Type:                  {t_type}")
        
        # Step 5: Critical Temperature (Nested inside 'crit_trans')
        if trans.get('crit_trans') is not None:
            Tc = trans['crit_trans']['Tcrit']
            print(f"  Critical Temp (Tc):    {Tc:.4f} GeV")
        else:
            print(f"  Critical Temp (Tc):    N/A (Continuous transition)")
            
        # Step 6: Nucleation Temperature (Sits at the root of the dict)
        Tnuc = trans.get('Tnuc')
        if Tnuc is not None:
            print(f"  Nucleation Temp (Tn):  {Tnuc:.4f} GeV")
            print(f"  Action at nucleation:  S3/T = {trans.get('action'):.2f}")
        else:
            print(f"  Nucleation Temp (Tn):  N/A (Symmetry did not break or no tunneling found)")
            
        print(f"  High-T phase minimum:  {trans['high_vev']}")
        print(f"  Low-T phase minimum:   {trans['low_vev']}")
# Out:
# Running phase tracking loops...
# Tracing phase starting at x = [-29.32870258] ; t = 0.0
# Tracing minimum up
# traceMinimum t0 = 0
# ............................................................
# Tracing phase starting at x = [-1.73472348e-18] ; t = 34.140289990294285
# Tracing minimum down
# traceMinimum t0 = 34.1403
# ......................
# Tracing minimum up
# traceMinimum t0 = 34.1403
# .................
# Tracing phase starting at x = [10.34587816] ; t = 32.97185724788978
# Tracing minimum down
# traceMinimum t0 = 32.9719
# ........................................
# Tracing minimum up
# traceMinimum t0 = 32.9719
# ..................
# Tunneling from phase 0 to phase 2 at T=0
# high_vev = [-29.32870261]
# low_vev = [29.32870242]
#
# --- Phase Transition Analysis Complete ---
#
# Transition #1:
#   Type:                  2nd Order
#   Critical Temp (Tc):    33.5552 GeV
#   Nucleation Temp (Tn):  33.5552 GeV
#   Action at nucleation:  S3/T = 0.00
# ...
