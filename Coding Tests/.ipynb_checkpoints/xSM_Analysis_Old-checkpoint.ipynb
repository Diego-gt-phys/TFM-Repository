# %% [markdown]
# # Real Singlet extension of the Standard Model

# %%
import numpy as np

import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
import matplotlib.lines as mlines
from matplotlib.cm import ScalarMappable
from matplotlib.colors import Normalize
from matplotlib.gridspec import GridSpec
from matplotlib.ticker import AutoMinorLocator
from matplotlib.colors import TwoSlopeNorm

from cosmoTransitions import pathDeformation, transitionFinder
from cosmoTransitions import pathDeformation

from scipy.optimize import minimize, brentq
from scipy.optimize import minimize_scalar

from xSM_Model import xSM

# %% [markdown]
# ## Limiting Test: SM

# %%
model = xSM()
v = model.v_os
res = minimize_scalar(
    lambda phi: model.Vtot(np.array([[phi, u]]), 0.0).item(),
    bounds=(50, 350),
    method='bounded'
)
v_num = res.x
print(f"Numerical vev (Vtot, T=0): {v_num:.3f} GeV")
print(f"CW shift: {abs(v_num - model.v_os) / model.v_os * 100:.3f}%")
# Out:
# Numerical vev (Vtot, T=0): 246.220 GeV
# CW shift: 0.000%

# %%
h_vals = np.linspace(-500, 500, 1500)
X = np.column_stack([h_vals, np.zeros_like(h_vals)])

V_tree   = model.V0(X)
V_tot_0  = model.Vtot(X, 0.0)

fig, ax = plt.subplots(figsize=(9.7, 6))

ax.axhline(0, color='k', lw=1, ls='-')
ax.axvline(0, color='k', lw=1, ls='-')

ax.plot(h_vals, V_tot_0-model.Vtot(np.array([[0.0, 0.0]]), 0.0), label=r'$V_0 + V_\mathrm{CW}$', color='r', lw=1.5, ls='-')
ax.plot(h_vals, V_tree-model.V0(np.array([[0.0, 0.0]])), label=r'$V_0$', color='b', lw=1.5, ls='-.')

ax.axvline(v_num, label=rf'$v={float(np.squeeze(v_num)):.0f} \, \mathrm{{GeV}}$', color='gray', lw=1.0, ls='-', alpha=1)
ax.axvline(v, label=rf'$v_0={v:.0f} \, \mathrm{{GeV}}$', color='gray', lw=1.5, ls='-.', alpha=1)

ax.set_xlim(0, 370)
ax.set_ylim(-1.4e8, 2e7)

ax.set_xlabel(r'$h$ $\left[\mathrm{GeV}\right]$', fontsize=18)
ax.set_ylabel(r'$V_\mathrm{eff}\,(h)$ $\left[\mathrm{GeV^4}\right]$', fontsize=18)
ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
ax.ticklabel_format(style='sci', axis='y', scilimits=(-2, 2))
ax.yaxis.get_offset_text().set_fontsize(15)
ax.spines['top'].set_linewidth(1.5)
ax.spines['right'].set_linewidth(1.5)
ax.spines['bottom'].set_linewidth(1.5)
ax.spines['left'].set_linewidth(1.5)

ax.tick_params(axis='both', which='major', direction='in', length=8, width=1.2, labelsize=15, top=True, right=True)
ax.tick_params(axis='both', which='minor', direction='in', length=4, width=1, labelsize=15, top=True, right=True)
ax.minorticks_on()
ax.tick_params(axis='x', which='major', pad=5)

plt.legend(fontsize=18, frameon=True, fancybox=False, loc = "lower left", bbox_to_anchor=(0.01, 0.003),
               ncol = 1, edgecolor="black", framealpha=0, labelspacing=0.2, handletextpad=0.3, handlelength=1, columnspacing=1)

plt.title(r"Coleman-Weinber: Standard Model", loc='left', fontsize=20, fontweight='bold')
plt.tight_layout()
plt.savefig("Figures\SM_CW.pdf", format="pdf", bbox_inches="tight")

plt.show()

# %% [markdown]
# ## Define the Model

# %%
def physical_to_lagrangian(m1, m2, theta, v, u, lHS, lS):
    """
    Convert physical parameters to xSM Lagrangian parameters.

    Inputs
    ------
    m1, m2  : scalar mass eigenvalues (GeV), m1 < m2 convention
    theta   : mixing angle (rad)
    v, u    : Higgs and singlet vevs (GeV)
    lHS     : quartic portal lambda_HS
    lS      : singlet quartic lambda_S

    Outputs
    -------
    dict with keys: lH, muHS, mu3, muH2, muS2
    (lHS and lS are inputs, returned unchanged for completeness)
    """
    ct = np.cos(theta)
    st = np.sin(theta)

    # Mass matrix elements from eigenvalues + rotation
    Mhh = m1**2 * ct**2 + m2**2 * st**2
    Mss = m1**2 * st**2 + m2**2 * ct**2
    Mhs = (m1**2 - m2**2) * ct * st

    # Quartic couplings from diagonal mass matrix elements
    lH   = Mhh / (2.0 * v**2)

    # Off-diagonal: Mhs = lHS*v*u + muHS*v  =>  muHS = Mhs/v - lHS*u
    muHS = Mhs / v  -  lHS * u

    # Singlet diagonal: Mss = 2*lS*u^2 - mu3*u - muHS*v^2/(2u)
    # => mu3 = (2*lS*u^2 - Mss - muHS*v^2/(2u)) / u
    if abs(u) > 1e-6:
        mu3 = (2.0*lS*u**2  -  Mss  -  muHS*v**2/(2.0*u)) / u
    else:
        mu3 = 0.0   # u=0: mu3 is unconstrained, set to zero

    # Mass parameters from tadpole conditions
    muH2 = lH*v**2  +  0.5*lHS*u**2  +  muHS*u
    if abs(u) > 1e-6:
        muS2 = 0.5*lHS*v**2  +  muHS*v**2/(2.0*u)  +  lS*u**2  -  mu3*u
    else:
        muS2 = 0.0

    return dict(lH=lH, lHS=lHS, muHS=muHS, lS=lS, mu3=mu3, muH2=muH2, muS2=muS2)

# %%
v0 = 246.22
u0 = 200.0
params = physical_to_lagrangian(
    m1    = 125.20,   # GeV  -- SM-like Higgs, fixed
    m2    = 60.0,    # GeV  -- singlet-like scalar, not too heavy
    theta = 0.1,      # rad  -- moderate mixing, enhances cubic
    v     = v0,   # GeV
    u     = u0,     # GeV  -- Careful: If u is small and m2 is light, the potential can be unstable
    lHS   = 0.25,     #      -- portal, moderate
    lS    = 0.125,      #      -- large singlet self-coupling strengthens barrier
)
print(params)

model = xSM(**{k: params[k] for k in ['lH','lHS','muHS','lS','mu3']},
            v=v0, u=u0)
v = model.v_os
u = model.u_os

res = minimize(
    lambda x: model.Vtot(np.array([[x[0], x[1]]]), 0.0).item(),
    x0=[1, 1],          # start from the tree-level vevs
    bounds=[(0, 350), (0, 350)],
    method='L-BFGS-B'
)
v_num, u_num = res.x
print(f"Numerical vevs (Vtot, T=0): v = {v_num:.3f} GeV,  u = {u_num:.3f} GeV")
print(f"CW shift v: {abs(v_num - model.v_os) / model.v_os * 100:.3f}%")
print(f"CW shift u: {abs(u_num - model.u_os) / model.u_os * 100:.3f}%")
# Out:
# {'lH': 0.12828762180611472, 'lHS': 0.25, 'muHS': -45.12846211493056, 'lS': 0.125, 'mu3': 65.59676910404056, 'muH2': 3751.653359537917, 'muS2': -7381.020026568172}
# Numerical vevs (Vtot, T=0): v = 246.220 GeV,  u = 199.998 GeV
# CW shift v: 0.000%
# CW shift u: 0.001%

# %% [markdown]
# # Effective Potential at $T=0$

# %% [markdown]
# ### 1D Plot

# %%
h_vals = np.linspace(-500, 500, 1500)
X = np.column_stack([h_vals, np.zeros_like(h_vals)+u])

V_tree   = model.V0(X)
V_tot_0  = model.Vtot(X, 0.0)

fig, ax = plt.subplots(figsize=(9.7, 6))

ax.axhline(0, color='k', lw=1, ls='-')
ax.axvline(0, color='k', lw=1, ls='-')

ax.plot(h_vals, V_tot_0-model.Vtot(np.array([[0.0, u]]), 0.0), label=r'$V_0 + V_\mathrm{CW}$', color='r', lw=1.5, ls='-')
ax.plot(h_vals, V_tree-model.V0(np.array([[0.0, u]])), label=r'$V_0$', color='b', lw=1.5, ls='-.')

ax.axvline(v_num, label=rf'$v={float(np.squeeze(v_num)):.0f} \, \mathrm{{GeV}}$', color='gray', lw=1.0, ls='-', alpha=1)
ax.axvline(v, label=rf'$v_0={v:.0f} \, \mathrm{{GeV}}$', color='gray', lw=1.5, ls='-.', alpha=1)

ax.set_xlim(0, 370)
ax.set_ylim(-1.4e8, 2e7)

ax.set_xlabel(r'$\varphi_h$ $\left[\mathrm{GeV}\right]$', fontsize=18)
ax.set_ylabel(r'$V_\mathrm{eff}\,(\varphi_h)$ $\left[\mathrm{GeV^4}\right]$', fontsize=18)
ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
ax.ticklabel_format(style='sci', axis='y', scilimits=(-2, 2))
ax.yaxis.get_offset_text().set_fontsize(15)
ax.spines['top'].set_linewidth(1.5)
ax.spines['right'].set_linewidth(1.5)
ax.spines['bottom'].set_linewidth(1.5)
ax.spines['left'].set_linewidth(1.5)

ax.tick_params(axis='both', which='major', direction='in', length=8, width=1.2, labelsize=15, top=True, right=True)
ax.tick_params(axis='both', which='minor', direction='in', length=4, width=1, labelsize=15, top=True, right=True)
ax.minorticks_on()
ax.tick_params(axis='x', which='major', pad=5)

plt.legend(fontsize=18, frameon=True, fancybox=False, loc = "lower left", bbox_to_anchor=(0.01, 0.003),
               ncol = 1, edgecolor="black", framealpha=0, labelspacing=0.2, handletextpad=0.3, handlelength=1, columnspacing=1)

plt.title(r"Coleman-Weinber", loc='left', fontsize=20, fontweight='bold')
plt.tight_layout()
plt.savefig("Figures\CW.pdf", format="pdf", bbox_inches="tight")

plt.show()

# %% [markdown]
# ### 2D Contour Plot

# %%
# Grid in (h, s)
h_vals = np.linspace(0, 350, 700)
s_vals = np.linspace(0, 400, 700)
H, S   = np.meshgrid(h_vals, s_vals)
X_grid = np.column_stack([H.ravel(), S.ravel()])
V_grid = model.Vtot(X_grid, 0.0).reshape(H.shape)
V_plot = np.clip(V_grid, np.percentile(V_grid, 0), np.percentile(V_grid, 99))
V_shifted = V_plot - model.Vtot(np.array([[0.0, 0.0]]), 0.0)

norm = TwoSlopeNorm(vcenter=0, vmin=V_shifted.min(), vmax=V_shifted.max())
sm   = ScalarMappable(cmap='RdBu_r', norm=norm)

fig, ax = plt.subplots(figsize=(8.5, 6))

cp = ax.contourf(H, S, V_shifted, levels=50, cmap='RdBu_r', norm=norm)
ax.contour(H, S, V_shifted, levels=50, colors='k', linewidths=0.5, alpha=1)
ax.plot(v_num, u_num, 'w*', markersize=15, zorder=5, markeredgecolor='k', markeredgewidth=0.5,
        label=rf'$\langle\varphi_h, \varphi_s\rangle = ({v_num:.2f},\,{u_num:.0f})$ GeV')

ax.set_xlabel(r'$\varphi_h \, [\mathrm{GeV}]$', fontsize=18)
ax.set_ylabel(r'$\varphi_s \, [\mathrm{GeV}]$', fontsize=18)
ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
ax.ticklabel_format(style='sci', axis='y', scilimits=(-2, 2))
ax.yaxis.get_offset_text().set_fontsize(15)

for spine in ax.spines.values():
    spine.set_linewidth(1.5)

ax.tick_params(axis='both', which='major', direction='in',
               length=8, width=1.2, labelsize=15, top=True, right=True)
ax.tick_params(axis='both', which='minor', direction='in',
               length=4, width=1,   labelsize=15, top=True, right=True)
ax.minorticks_on()

cbar = fig.colorbar(sm, ax=ax, pad=0.01)
cbar.set_label(r'$V_\mathrm{eff}(\varphi_h,\varphi_s) \, [\mathrm{GeV^4}]$', fontsize=18)
cbar.ax.tick_params(labelsize=15)
cbar.ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
cbar.ax.yaxis.get_offset_text().set_fontsize(15)
plt.ticklabel_format(style='sci', axis='y', scilimits=(-2,3))
for spine in cbar.ax.spines.values():
    spine.set_linewidth(1.5)
cbar.ax.tick_params(axis='both', which='major', direction='in',
               length=8, width=1.2, labelsize=15)

ax.legend(fontsize=18, frameon=True, fancybox=False, loc = "lower left", bbox_to_anchor=(0.01, 0.01),
               ncol = 1, edgecolor="black", framealpha=0.9, labelspacing=0.2, handletextpad=0.3, handlelength=1, columnspacing=1)

plt.title(r"Effective Potential at T=0", loc='left', fontsize=20, fontweight='bold')
plt.tight_layout()
plt.savefig(r"Figures\CW_contour.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# # Phase Transitions

# %%
model.findAllTransitions()
print()
print("The Model has",len(model.TnTrans),"transition(s)")
# Out:
# Tracing phase starting at x = [246.22000044 200.00000251] ; t = 0.0
# Tracing minimum up
# traceMinimum t0 = 0
# .....................................................................................................................................................................................................................................................................
# Tracing phase starting at x = [1.54851093e-05 3.48521610e+02] ; t = 127.63725517979087
# Tracing minimum down
# traceMinimum t0 = 127.637
# .................................................................
# Tracing minimum up
# traceMinimum t0 = 127.637
# ...................................................................................................................................................................................
# Tracing phase starting at x = [4.71993643e-03 3.49374867e+02] ; t = 123.88643434473488
# Tracing minimum down
# traceMinimum t0 = 123.886
# ..........
# Tracing minimum up
# traceMinimum t0 = 123.886
# ..........
# Tunneling from phase 1 to phase 0 at T=124.8866
# high_vev = [-1.08938952e-03  3.49152453e+02]
# low_vev = [150.77849284 274.94137934]
# Path deformation converged. 16 steps. fRatio = 9.25734e-03
# Path deformation converged. 12 steps. fRatio = 1.38035e-02
# Path deformation converged. 1 steps. fRatio = 1.18454e-02
# Tunneling from phase 1 to phase 0 at T=124.8871
# high_vev = [-1.10408083e-03  3.49152335e+02]
# low_vev = [150.77338631 274.94702769]
# Path deformation converged. 16 steps. fRatio = 9.22525e-03
# Path deformation converged. 12 steps. fRatio = 1.46965e-02
# Path deformation converged. 1 steps. fRatio = 1.22444e-02
# Tunneling from phase 1 to phase 0 at T=125.7614
# high_vev = [8.99404191e-06 3.48954818e+02]
# low_vev = [139.29778805 287.04626861]
# Path deformation converged. 15 steps. fRatio = 7.33372e-03
# Path deformation converged. 9 steps. fRatio = 1.78787e-02
# Path deformation converged. 1 steps. fRatio = 1.11056e-02
# Tunneling from phase 1 to phase 0 at T=126.1985
# high_vev = [-4.68542739e-06  3.48855003e+02]
# low_vev = [129.78069645 296.12002156]
# Path deformation converged. 15 steps. fRatio = 2.48664e-03
# Path deformation converged. 11 steps. fRatio = 1.53812e-02
# Path deformation converged. 1 steps. fRatio = 1.51531e-02
# Tunneling from phase 1 to phase 0 at T=125.7798
# high_vev = [4.50757216e-05 3.48950604e+02]
# low_vev = [138.97426202 287.36931403]
# Path deformation converged. 15 steps. fRatio = 5.83112e-03
# Path deformation converged. 9 steps. fRatio = 1.40176e-02
# Path deformation converged. 1 steps. fRatio = 1.06455e-02
# Tunneling from phase 1 to phase 0 at T=125.8716
# high_vev = [3.3292477e-05 3.4892970e+02]
# low_vev = [137.28968856 289.03488881]
# Path deformation converged. 13 steps. fRatio = 1.32442e-02
# Path deformation converged. 9 steps. fRatio = 2.36870e-03
# Path deformation converged. 1 steps. fRatio = 1.20070e-02
# Tunneling from phase 1 to phase 0 at T=125.8541
# high_vev = [-2.38584730e-05  3.48933686e+02]
# low_vev = [137.62146245 288.70905406]
# Path deformation converged. 14 steps. fRatio = 9.16127e-03
# Path deformation converged. 9 steps. fRatio = 3.72620e-03
# Path deformation converged. 1 steps. fRatio = 1.13196e-02
# Tunneling from phase 1 to phase 0 at T=125.8575
# high_vev = [-1.94016467e-05  3.48932920e+02]
# low_vev = [137.55799774 288.77146532]
# Path deformation converged. 13 steps. fRatio = 1.93870e-02
# Path deformation converged. 9 steps. fRatio = 3.52127e-03
# Path deformation converged. 1 steps. fRatio = 1.16252e-02
# Tunneling from phase 1 to phase 0 at T=125.858
# high_vev = [3.11495769e-05 3.48932808e+02]
# low_vev = [137.54854374 288.78076262]
# Path deformation converged. 13 steps. fRatio = 1.91630e-02
# Path deformation converged. 9 steps. fRatio = 3.47586e-03
# Path deformation converged. 1 steps. fRatio = 1.16467e-02
#
# The Model has 1 transition(s)

# %%
Trans = model.TnTrans[0]

Tc    = Trans['crit_trans']['Tcrit']
highc = Trans['crit_trans']['high_vev']
lowc  = Trans['crit_trans']['low_vev']
xic   = abs(lowc[0] - highc[0]) / Tc
Tn    = Trans['Tnuc']
highn = Trans['high_vev']
lown  = Trans['low_vev']
xin   = abs(lown[0] - highn[0]) / Tc

# %%
T_nuc   = Trans['Tnuc']          # 125.86 GeV
Drho    = Trans['Delta_rho']     # latent heat (already computed by CT)

g_star  = 106.75  # SM + singlet; adjust if needed
rho_rad = (np.pi**2 / 30) * g_star * T_nuc**4

alpha   = Drho / rho_rad
print(f"alpha = {alpha:.4f}")
# Out:
# alpha = 0.0103

# %%
path_points = Trans['instanton'].Phi

# Grid in (h, s)
h_vals = np.linspace(-10, 140, 500)
s_vals = np.linspace(290, 360, 500)
H, S   = np.meshgrid(h_vals, s_vals)
X_grid = np.column_stack([H.ravel(), S.ravel()])
V_grid = model.Vtot(X_grid, Tc).reshape(H.shape)
V_plot = np.clip(V_grid, np.percentile(V_grid, 0), np.percentile(V_grid, 90))
V_shifted = V_plot - model.Vtot(np.array([[0.0, 0.0]]), Tc)

norm = Normalize(vmin=V_shifted.min(), vmax=V_shifted.max())
sm   = ScalarMappable(cmap='RdBu_r', norm=norm)

fig, ax = plt.subplots(figsize=(8.5, 6))

cp = ax.contourf(H, S, V_shifted, levels=55, cmap='RdBu_r', norm=norm)
ax.contour(H, S, V_shifted, levels=55, colors='k', linewidths=0.3, alpha=1)

ax.plot(path_points[:, 0], path_points[:, 1], label='Tunneling path', color='w', lw=2.5, ls='-')
ax.plot(path_points[-1, 0], path_points[-1, 1], 'r*', markersize=15, zorder=5, markeredgecolor='k', markeredgewidth=0.5,
        label=rf'High Phase ({path_points[-1, 0]:.0f}, {path_points[-1, 1]:.0f}) GeV')
ax.plot(path_points[0, 0], path_points[0, 1], 'b*', markersize=15, zorder=5, markeredgecolor='k', markeredgewidth=0.5,
        label=rf'Low Phase ({path_points[0, 0]:.0f}, {path_points[0, 1]:.0f}) GeV')

ax.set_xlabel(r'$\varphi_h \, [\mathrm{GeV}]$', fontsize=18)
ax.set_ylabel(r'$\varphi_s \, [\mathrm{GeV}]$', fontsize=18)
ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
ax.ticklabel_format(style='sci', axis='y', scilimits=(-2, 2))
ax.yaxis.get_offset_text().set_fontsize(15)

for spine in ax.spines.values():
    spine.set_linewidth(1.5)

ax.tick_params(axis='both', which='major', direction='in',
               length=8, width=1.2, labelsize=15, top=True, right=True)
ax.tick_params(axis='both', which='minor', direction='in',
               length=4, width=1,   labelsize=15, top=True, right=True)
ax.minorticks_on()

cbar = fig.colorbar(sm, ax=ax, pad=0.01)
cbar.set_label(r'$V_\mathrm{eff}(\varphi_h,\varphi_s) \, [\mathrm{GeV^4}]$', fontsize=18)
cbar.ax.tick_params(labelsize=15)
cbar.ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
cbar.ax.yaxis.get_offset_text().set_fontsize(15)
plt.ticklabel_format(style='sci', axis='y', scilimits=(-2,3))
for spine in cbar.ax.spines.values():
    spine.set_linewidth(1.5)
cbar.ax.tick_params(axis='both', which='major', direction='in',
               length=8, width=1.2, labelsize=15)

ax.legend(fontsize=18, frameon=True, fancybox=False, loc = "lower left", bbox_to_anchor=(0.01, 0.01), 
          ncol = 1, edgecolor="black", framealpha=0.65, labelspacing=0.2, handletextpad=0.3, handlelength=1, columnspacing=1)

annotation = (rf"$T_c   = {Tc:.2f} \, \mathrm{{GeV}}$"
              "\n"rf"$T_n = {Tn:.2f} \, \mathrm{{GeV}}$"
              "\n"rf"$\xi_n = {xin:.1f}$")
ax.text(0.96, 0.95, annotation,transform=ax.transAxes,fontsize=18,verticalalignment='top',horizontalalignment='right',
       bbox=dict(facecolor='white', edgecolor='black', alpha=0.65))

plt.title(rf"Effective Potential at critical temp", loc='left', fontsize=20, fontweight='bold')
plt.tight_layout()
plt.savefig(r"Figures\Tc_contour.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# # Parameter Study

# %%
def physical_to_lagrangian(m1, m2, theta, v, u, lHS, lS):
    """
    Convert physical parameters to xSM Lagrangian parameters.

    Inputs
    ------
    m1, m2  : scalar mass eigenvalues (GeV), m1 < m2 convention
    theta   : mixing angle (rad)
    v, u    : Higgs and singlet vevs (GeV)
    lHS     : quartic portal lambda_HS
    lS      : singlet quartic lambda_S

    Outputs
    -------
    dict with keys: lH, muHS, mu3, muH2, muS2
    (lHS and lS are inputs, returned unchanged for completeness)
    """
    ct = np.cos(theta)
    st = np.sin(theta)
    
    Mhh = m1**2 * ct**2 + m2**2 * st**2
    Mss = m1**2 * st**2 + m2**2 * ct**2
    Mhs = (m1**2 - m2**2) * ct * st
    
    lH   = Mhh / (2.0 * v**2)

    muHS = Mhs / v  -  lHS * u

    # Relations don't hold if u=0
    if abs(u) > 1e-6:
        mu3 = (2.0*lS*u**2  -  Mss  -  muHS*v**2/(2.0*u)) / u
    else:
        mu3 = 0.0   

    # Mass parameters from tadpole conditions
    muH2 = lH*v**2  +  0.5*lHS*u**2  +  muHS*u
    if abs(u) > 1e-6:
        muS2 = 0.5*lHS*v**2  +  muHS*v**2/(2.0*u)  +  lS*u**2  -  mu3*u
    else:
        muS2 = 0.0

    return dict(lH=lH, lHS=lHS, muHS=muHS, lS=lS, mu3=mu3, muH2=muH2, muS2=muS2)

# %% [markdown]
# ## Unstable Potential

# %%
import time
# Define the parameters
v0 = 246.22
u0 = 50.0
params = physical_to_lagrangian(
    m1    = 125.20,   # GeV  
    m2    = 60.0,    # GeV 
    theta = 0.01,      # rad  
    v     = v0,   # GeV
    u     = u0,     # GeV 
    lHS   = 0.25,     #     
    lS    = 0.125,      #     
)
print(params)

model = xSM(**{k: params[k] for k in ['lH','lHS','muHS','lS','mu3']},
            v=v0, u=u0)
v = model.v_os
u = model.u_os
start_time = time.perf_counter()
# Find the numeric minima
res = minimize(
    lambda x: model.Vtot(np.array([[x[0], x[1]]]), 0.0).item(),
    x0=[300, 500],          
    bounds=[(0, 350), (-500, 2000)],
    method='L-BFGS-B'
)
end_time = time.perf_counter()
execution_time = end_time - start_time
v_num, u_num = res.x

print(f"Numerical vev: ({v_num:.2f},{u_num:.2f}) GeV")
print(execution_time)
# Out:
# {'lH': 0.1292702392878693, 'lHS': 0.25, 'muHS': -12.00961599328108, 'lS': 0.125, 'mu3': 86.09073543497686, 'muH2': 7548.935468460744, 'muS2': -3694.74495724809}
# Numerical vev: (0.00,1804.98) GeV
# 0.06754129999899305

# %% [markdown]
# ### Tree Level Potential

# %%
# Grid in (h, s)
h_vals = np.linspace(-350, 350, 200)
s_vals = np.linspace(-100, 850, 200)
H, S   = np.meshgrid(h_vals, s_vals)
X_grid = np.column_stack([H.ravel(), S.ravel()])
V_grid = model.V0(X_grid).reshape(H.shape)
V_plot = np.clip(V_grid, np.percentile(V_grid, 0), np.percentile(V_grid, 99))
V_shifted = V_plot - model.Vtot(np.array([[0.0, 0.0]]), 0.0)

norm = TwoSlopeNorm(vcenter=0, vmin=V_shifted.min(), vmax=V_shifted.max())
sm   = ScalarMappable(cmap='RdBu_r', norm=norm)

fig, ax = plt.subplots(figsize=(8.5, 6))

cp = ax.contourf(H, S, V_shifted, levels=50, cmap='RdBu_r', norm=norm)
ax.contour(H, S, V_shifted, levels=50, colors='k', linewidths=0.5, alpha=1)
ax.plot(v, u, 'w*', markersize=15, zorder=5, markeredgecolor='k', markeredgewidth=0.5,label=rf'$\langle\varphi_h, \varphi_s\rangle = ({v:.2f},\,{u:.0f})$ GeV')

ax.set_xlabel(r'$\varphi_h \, [\mathrm{GeV}]$', fontsize=18)
ax.set_ylabel(r'$\varphi_s \, [\mathrm{GeV}]$', fontsize=18)
ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
ax.ticklabel_format(style='sci', axis='y', scilimits=(-2, 2))
ax.yaxis.get_offset_text().set_fontsize(15)

for spine in ax.spines.values():
    spine.set_linewidth(1.5)

ax.tick_params(axis='both', which='major', direction='in',
               length=8, width=1.2, labelsize=15, top=True, right=True)
ax.tick_params(axis='both', which='minor', direction='in',
               length=4, width=1,   labelsize=15, top=True, right=True)
ax.minorticks_on()

cbar = fig.colorbar(sm, ax=ax, pad=0.01)
cbar.set_label(r'$V_\mathrm{eff}(\varphi_h,\varphi_s) \, [\mathrm{GeV^4}]$', fontsize=18)
cbar.ax.tick_params(labelsize=15)
cbar.ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
cbar.ax.yaxis.get_offset_text().set_fontsize(15)
plt.ticklabel_format(style='sci', axis='y', scilimits=(-2,3))
for spine in cbar.ax.spines.values():
    spine.set_linewidth(1.5)
cbar.ax.tick_params(axis='both', which='major', direction='in',
               length=8, width=1.2, labelsize=15)

ax.legend(fontsize=18, frameon=True, fancybox=False, loc = "center", bbox_to_anchor=(0.5, 0.5),ncol = 1, edgecolor="black", framealpha=0.9, labelspacing=0.2, handletextpad=0.3, handlelength=1, columnspacing=1)

plt.title(r"Tree Level Potential at T=0", loc='left', fontsize=20, fontweight='bold')
plt.tight_layout()
plt.savefig(r"Figures\Unstable_V0_contour.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Coleman-Weinberg

# %%
# Grid in (h, s)
h_vals = np.linspace(-400, 400, 200)
s_vals = np.linspace(-100, 2500, 200)
H, S   = np.meshgrid(h_vals, s_vals)
X_grid = np.column_stack([H.ravel(), S.ravel()])
V_grid = model.Vtot(X_grid, 0.0).reshape(H.shape)
V_plot = np.clip(V_grid, np.percentile(V_grid, 0), np.percentile(V_grid, 99))
V_shifted = V_plot - model.Vtot(np.array([[0.0, 0.0]]), 0.0)

norm = Normalize(vmin=V_shifted.min(), vmax=V_shifted.max()) # Normalize(vmin=V_shifted.min(), vmax=V_shifted.max())
sm   = ScalarMappable(cmap='RdBu_r', norm=norm)

fig, ax = plt.subplots(figsize=(8.5, 6))

cp = ax.contourf(H, S, V_shifted, levels=50, cmap='RdBu_r', norm=norm)
ax.contour(H, S, V_shifted, levels=50, colors='k', linewidths=0.5, alpha=1)
ax.plot(v, u, 'w*', markersize=15, zorder=5, markeredgecolor='k', markeredgewidth=0.5,
        label=rf'$\langle\varphi_h, \varphi_s\rangle = ({v:.2f},\,{u:.0f})$ GeV')

ax.set_xlabel(r'$\varphi_h \, [\mathrm{GeV}]$', fontsize=18)
ax.set_ylabel(r'$\varphi_s \, [\mathrm{GeV}]$', fontsize=18)
ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
ax.ticklabel_format(style='sci', axis='y', scilimits=(-2, 2))
ax.yaxis.get_offset_text().set_fontsize(15)

for spine in ax.spines.values():
    spine.set_linewidth(1.5)

ax.tick_params(axis='both', which='major', direction='in',
               length=8, width=1.2, labelsize=15, top=True, right=True)
ax.tick_params(axis='both', which='minor', direction='in',
               length=4, width=1,   labelsize=15, top=True, right=True)
ax.minorticks_on()

cbar = fig.colorbar(sm, ax=ax, pad=0.01)
cbar.set_label(r'$V_\mathrm{eff}(\varphi_h,\varphi_s) \, [\mathrm{GeV^4}]$', fontsize=18)
cbar.ax.tick_params(labelsize=15)
cbar.ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
cbar.ax.yaxis.get_offset_text().set_fontsize(15)
plt.ticklabel_format(style='sci', axis='y', scilimits=(-2,3))
for spine in cbar.ax.spines.values():
    spine.set_linewidth(1.5)
cbar.ax.tick_params(axis='both', which='major', direction='in',
               length=8, width=1.2, labelsize=15)

ax.legend(fontsize=18, frameon=True, fancybox=False, loc = "upper center", bbox_to_anchor=(0.5, 0.5),
               ncol = 1, edgecolor="black", framealpha=0.9, labelspacing=0.2, handletextpad=0.3, handlelength=1, columnspacing=1)

plt.title(r"Coleman-Weinberg at T=0", loc='left', fontsize=20, fontweight='bold')
plt.tight_layout()
plt.savefig(r"Figures\Unstable_V1_contour.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## No mixing limit $\theta \to 0$

# %%
# Define the parameters
v0 = 246.22
u0 = 200.0
params = physical_to_lagrangian(
    m1    = 125.20,   # GeV  
    m2    = 60.0,    # GeV 
    theta = 0,      # rad  
    v     = v0,   # GeV
    u     = u0,     # GeV 
    lHS   = 0.25,     #     
    lS    = 0.125,      #     
)
print(params)

model = xSM(**{k: params[k] for k in ['lH','lHS','muHS','lS','mu3']},
            v=v0, u=u0)
v = model.v_os
u = model.u_os

# Find the numeric minima
res = minimize(
    lambda x: model.Vtot(np.array([[x[0], x[1]]]), 0.0).item(),
    x0=[1, 1],          
    bounds=[(0, 350), (0, 700)],
    method='L-BFGS-B'
)
v_num, u_num = res.x

print(f"Numerical vev: ({v_num:.2f},{u_num:.2f}) GeV")
# Out:
# {'lH': 0.1292801978686813, 'lHS': 0.25, 'muHS': -50.0, 'lS': 0.125, 'mu3': 69.89018025, 'muH2': 2837.5200000000004, 'muS2': -8978.03605}
# Numerical vev: (246.22,200.00) GeV

# %% [markdown]
# ### Tree level Potential

# %%
# Grid in (h, s)
h_vals = np.linspace(0, 350, 200)
s_vals = np.linspace(0, 400, 200)
H, S   = np.meshgrid(h_vals, s_vals)
X_grid = np.column_stack([H.ravel(), S.ravel()])
V_grid = model.V0(X_grid).reshape(H.shape)
V_plot = np.clip(V_grid, np.percentile(V_grid, 0), np.percentile(V_grid, 99))
V_shifted = V_plot - model.V0(np.array([[0.0, 0.0]]))

norm = TwoSlopeNorm(vcenter=0, vmin=V_shifted.min(), vmax=V_shifted.max())
sm   = ScalarMappable(cmap='RdBu_r', norm=norm)

fig, ax = plt.subplots(figsize=(8.5, 6))

cp = ax.contourf(H, S, V_shifted, levels=50, cmap='RdBu_r', norm=norm)
ax.contour(H, S, V_shifted, levels=50, colors='k', linewidths=0.5, alpha=1)
ax.plot(v, u, 'w*', markersize=15, zorder=5, markeredgecolor='k', markeredgewidth=0.5,label=rf'$\langle\varphi_h, \varphi_s\rangle = ({v:.2f},\,{u:.0f})$ GeV')

ax.set_xlabel(r'$\varphi_h \, [\mathrm{GeV}]$', fontsize=18)
ax.set_ylabel(r'$\varphi_s \, [\mathrm{GeV}]$', fontsize=18)
ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
ax.ticklabel_format(style='sci', axis='y', scilimits=(-2, 2))
ax.yaxis.get_offset_text().set_fontsize(15)

for spine in ax.spines.values():
    spine.set_linewidth(1.5)

ax.tick_params(axis='both', which='major', direction='in',
               length=8, width=1.2, labelsize=15, top=True, right=True)
ax.tick_params(axis='both', which='minor', direction='in',
               length=4, width=1,   labelsize=15, top=True, right=True)
ax.minorticks_on()

cbar = fig.colorbar(sm, ax=ax, pad=0.01)
cbar.set_label(r'$V_\mathrm{eff}(\varphi_h,\varphi_s) \, [\mathrm{GeV^4}]$', fontsize=18)
cbar.ax.tick_params(labelsize=15)
cbar.ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
cbar.ax.yaxis.get_offset_text().set_fontsize(15)
plt.ticklabel_format(style='sci', axis='y', scilimits=(-2,3))
for spine in cbar.ax.spines.values():
    spine.set_linewidth(1.5)
cbar.ax.tick_params(axis='both', which='major', direction='in',
               length=8, width=1.2, labelsize=15)

ax.legend(fontsize=18, frameon=True, fancybox=False, loc = "upper left", bbox_to_anchor=(0.01, 0.99),ncol = 1, edgecolor="black", framealpha=0.9, labelspacing=0.2, handletextpad=0.3, handlelength=1, columnspacing=1)

plt.title(r"Tree Level Potential at T=0", loc='left', fontsize=20, fontweight='bold')
plt.tight_layout()
plt.savefig(r"Figures\Ummix_V0_contour.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Coleman Weinberg

# %%
# Grid in (h, s)
h_vals = np.linspace(0, 350, 200)
s_vals = np.linspace(0, 400, 200)
H, S   = np.meshgrid(h_vals, s_vals)
X_grid = np.column_stack([H.ravel(), S.ravel()])
V_grid = model.Vtot(X_grid, 0.0).reshape(H.shape)
V_plot = np.clip(V_grid, np.percentile(V_grid, 0), np.percentile(V_grid, 99))
V_shifted = V_plot - model.Vtot(np.array([[0.0, 0.0]]), 0.0)

norm = TwoSlopeNorm(vcenter=0, vmin=V_shifted.min(), vmax=V_shifted.max())
sm   = ScalarMappable(cmap='RdBu_r', norm=norm)

fig, ax = plt.subplots(figsize=(8.5, 6))

cp = ax.contourf(H, S, V_shifted, levels=50, cmap='RdBu_r', norm=norm)
ax.contour(H, S, V_shifted, levels=50, colors='k', linewidths=0.5, alpha=1)
ax.plot(v, u, 'w*', markersize=15, zorder=5, markeredgecolor='k', markeredgewidth=0.5,label=rf'$\langle\varphi_h, \varphi_s\rangle = ({v:.2f},\,{u:.0f})$ GeV')

ax.set_xlabel(r'$\varphi_h \, [\mathrm{GeV}]$', fontsize=18)
ax.set_ylabel(r'$\varphi_s \, [\mathrm{GeV}]$', fontsize=18)
ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
ax.ticklabel_format(style='sci', axis='y', scilimits=(-2, 2))
ax.yaxis.get_offset_text().set_fontsize(15)

for spine in ax.spines.values():
    spine.set_linewidth(1.5)

ax.tick_params(axis='both', which='major', direction='in',
               length=8, width=1.2, labelsize=15, top=True, right=True)
ax.tick_params(axis='both', which='minor', direction='in',
               length=4, width=1,   labelsize=15, top=True, right=True)
ax.minorticks_on()

cbar = fig.colorbar(sm, ax=ax, pad=0.01)
cbar.set_label(r'$V_\mathrm{eff}(\varphi_h,\varphi_s) \, [\mathrm{GeV^4}]$', fontsize=18)
cbar.ax.tick_params(labelsize=15)
cbar.ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
cbar.ax.yaxis.get_offset_text().set_fontsize(15)
plt.ticklabel_format(style='sci', axis='y', scilimits=(-2,3))
for spine in cbar.ax.spines.values():
    spine.set_linewidth(1.5)
cbar.ax.tick_params(axis='both', which='major', direction='in',
               length=8, width=1.2, labelsize=15)

ax.legend(fontsize=18, frameon=True, fancybox=False, loc = "upper left", bbox_to_anchor=(0.01, 0.99),ncol = 1, edgecolor="black", framealpha=0.9, labelspacing=0.2, handletextpad=0.3, handlelength=1, columnspacing=1)

plt.title(r"Coleman-Weinberg at T=0", loc='left', fontsize=20, fontweight='bold')
plt.tight_layout()
plt.savefig(r"Figures\Ummix_V1_contour.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Phase Transition

# %%
model.findAllTransitions()
print()
print("The Model has",len(model.TnTrans),"transition(s)")
# Out:
# Tracing phase starting at x = [246.21999962 199.99999848] ; t = 0.0
# Tracing minimum up
# traceMinimum t0 = 0
# ....................................................................................................................................................................................
# Tracing phase starting at x = [3.80719117e-06 1.57072835e+01] ; t = 131.5839433629703
# Tracing minimum down
# traceMinimum t0 = 131.584
# ..............................................................
# Tracing minimum up
# traceMinimum t0 = 131.584
# ..................................................................................................................................................................................
# Tunneling from phase 1 to phase 0 at T=115.9144
# high_vev = [-2.17055048e-05  1.18404403e+01]
# low_vev = [195.55096343 197.01511215]
# Path deformation converged. 43 steps. fRatio = 1.80228e-02
# Path deformation converged. 14 steps. fRatio = 3.51989e-03
# Path deformation converged. 6 steps. fRatio = 9.03126e-04
# Path deformation converged. 1 steps. fRatio = 1.07967e-04
# Tunneling from phase 1 to phase 0 at T=115.9149
# high_vev = [4.74850522e-05 1.18405522e+01]
# low_vev = [195.5501765  197.01500021]
# Path deformation converged. 43 steps. fRatio = 1.80214e-02
# Path deformation converged. 14 steps. fRatio = 3.53287e-03
# Path deformation converged. 6 steps. fRatio = 9.43010e-04
# Path deformation converged. 1 steps. fRatio = 1.48511e-04
# Tunneling from phase 1 to phase 0 at T=123.2489
# high_vev = [1.27606429e-05 1.35439757e+01]
# low_vev = [182.80527274 194.33919355]
# Path deformation converged. 43 steps. fRatio = 1.91352e-02
# Path deformation converged. 11 steps. fRatio = 1.10243e-02
# Path deformation converged. 1 steps. fRatio = 5.83036e-02
# Tunneling from phase 1 to phase 0 at T=116.0331
# high_vev = [-2.62588087e-05  1.18664991e+01]
# low_vev = [195.36426708 196.98947488]
# Path deformation converged. 38 steps. fRatio = 1.72946e-02
# Path deformation converged. 14 steps. fRatio = 5.96740e-03
# Path deformation converged. 8 steps. fRatio = 1.64213e-02
# Path deformation converged. 1 steps. fRatio = 1.12972e-02
# Tunneling from phase 1 to phase 0 at T=119.641
# high_vev = [5.03152034e-06 1.26824227e+01]
# low_vev = [189.39911715 196.00378617]
# Path deformation converged. 42 steps. fRatio = 1.66093e-02
# Path deformation converged. 11 steps. fRatio = 1.27475e-02
# Path deformation converged. 1 steps. fRatio = 6.66709e-02
# Tunneling from phase 1 to phase 0 at T=118.1088
# high_vev = [-3.53260923e-05  1.23302923e+01]
# low_vev = [192.00309523 196.47800381]
# Path deformation converged. 42 steps. fRatio = 1.93211e-02
# Path deformation converged. 13 steps. fRatio = 9.32756e-03
# Path deformation converged. 1 steps. fRatio = 8.41425e-02
# Tunneling from phase 1 to phase 0 at T=118.5715
# high_vev = [4.64497079e-06 1.24357712e+01]
# low_vev = [191.22805098 196.34488071]
# Path deformation converged. 43 steps. fRatio = 1.72251e-02
# Path deformation converged. 12 steps. fRatio = 1.93861e-02
# Path deformation converged. 1 steps. fRatio = 7.64750e-02
# Tunneling from phase 1 to phase 0 at T=118.7128
# high_vev = [-2.22213129e-05  1.24681185e+01]
# low_vev = [190.98952285 196.30260614]
# Path deformation converged. 43 steps. fRatio = 1.72437e-02
# Path deformation converged. 12 steps. fRatio = 1.65120e-02
# Path deformation converged. 1 steps. fRatio = 7.25336e-02
# Tunneling from phase 1 to phase 0 at T=118.7052
# high_vev = [4.32411645e-05 1.24663754e+01]
# low_vev = [191.00238512 196.30490029]
# Path deformation converged. 43 steps. fRatio = 1.72448e-02
# Path deformation converged. 12 steps. fRatio = 1.66568e-02
# Path deformation converged. 1 steps. fRatio = 7.27621e-02
# Tunneling from phase 1 to phase 0 at T=118.7057
# high_vev = [5.03252241e-06 1.24664886e+01]
# low_vev = [191.00153447 196.30475122]
# Path deformation converged. 43 steps. fRatio = 1.72447e-02
# Path deformation converged. 12 steps. fRatio = 1.66476e-02
# Path deformation converged. 1 steps. fRatio = 7.27521e-02
#
# The Model has 1 transition(s)

# %%
Trans = model.TnTrans[0]

Tc    = Trans['crit_trans']['Tcrit']
highc = Trans['crit_trans']['high_vev']
lowc  = Trans['crit_trans']['low_vev']
xic   = abs(lowc[0] - highc[0]) / Tc
Tn    = Trans['Tnuc']
highn = Trans['high_vev']
lown  = Trans['low_vev']
xin   = abs(lown[0] - highn[0]) / Tc

# %%
path_points = Trans['instanton'].Phi

# Grid in (h, s)
h_vals = np.linspace(-10, 210, 500)
s_vals = np.linspace(0, 300, 500)
H, S   = np.meshgrid(h_vals, s_vals)
X_grid = np.column_stack([H.ravel(), S.ravel()])
V_grid = model.Vtot(X_grid, Tc).reshape(H.shape)
V_plot = np.clip(V_grid, np.percentile(V_grid, 0), np.percentile(V_grid, 90))
V_shifted = V_plot - model.Vtot(np.array([[0.0, 0.0]]), Tc)

norm = Normalize(vmin=V_shifted.min(), vmax=V_shifted.max())
sm   = ScalarMappable(cmap='RdBu_r', norm=norm)

fig, ax = plt.subplots(figsize=(8.5, 6))

cp = ax.contourf(H, S, V_shifted, levels=55, cmap='RdBu_r', norm=norm)
ax.contour(H, S, V_shifted, levels=55, colors='k', linewidths=0.3, alpha=1)

#ax.plot(path_points[:, 0], path_points[:, 1], label='Tunneling path', color='w', lw=2.5, ls='-')
ax.plot(highc[0], highc[1], 'r*', markersize=15, zorder=5, markeredgecolor='k', markeredgewidth=0.5,
        label=rf'High Phase ({path_points[-1, 0]:.0f}, {path_points[-1, 1]:.0f}) GeV')
ax.plot(lowc[0], lowc[1], 'b*', markersize=15, zorder=5, markeredgecolor='k', markeredgewidth=0.5,
        label=rf'Low Phase ({path_points[0, 0]:.0f}, {path_points[0, 1]:.0f}) GeV')

ax.set_xlabel(r'$\varphi_h \, [\mathrm{GeV}]$', fontsize=18)
ax.set_ylabel(r'$\varphi_s \, [\mathrm{GeV}]$', fontsize=18)
ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
ax.ticklabel_format(style='sci', axis='y', scilimits=(-2, 2))
ax.yaxis.get_offset_text().set_fontsize(15)

for spine in ax.spines.values():
    spine.set_linewidth(1.5)

ax.tick_params(axis='both', which='major', direction='in',
               length=8, width=1.2, labelsize=15, top=True, right=True)
ax.tick_params(axis='both', which='minor', direction='in',
               length=4, width=1,   labelsize=15, top=True, right=True)
ax.minorticks_on()

cbar = fig.colorbar(sm, ax=ax, pad=0.01)
cbar.set_label(r'$V_\mathrm{eff}(\varphi_h,\varphi_s) \, [\mathrm{GeV^4}]$', fontsize=18)
cbar.ax.tick_params(labelsize=15)
cbar.ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
cbar.ax.yaxis.get_offset_text().set_fontsize(15)
plt.ticklabel_format(style='sci', axis='y', scilimits=(-2,3))
for spine in cbar.ax.spines.values():
    spine.set_linewidth(1.5)
cbar.ax.tick_params(axis='both', which='major', direction='in',
               length=8, width=1.2, labelsize=15)

ax.legend(fontsize=18, frameon=True, fancybox=False, loc = "upper left", bbox_to_anchor=(0.01, 0.99), 
          ncol = 1, edgecolor="black", framealpha=0.65, labelspacing=0.2, handletextpad=0.3, handlelength=1, columnspacing=1)

annotation = (rf"$T_c   = {Tc:.2f} \, \mathrm{{GeV}}$"
              "\n"rf"$T_n = {Tn:.2f} \, \mathrm{{GeV}}$"
              "\n"rf"$\xi_c = {xic:.1f}$")
ax.text(0.96, 0.05, annotation,transform=ax.transAxes,fontsize=18,verticalalignment='bottom',horizontalalignment='right',
       bbox=dict(facecolor='white', edgecolor='black', alpha=0.65))

plt.title(f"Effective Potential at {Tc:.2f} GeV", loc='left', fontsize=20, fontweight='bold')
plt.tight_layout()
plt.savefig(r"Figures\Unmix_Tc_contour.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
path_points = Trans['instanton'].Phi

# Grid in (h, s)
h_vals = np.linspace(-10, 220, 500)
s_vals = np.linspace(0, 300, 500)
H, S   = np.meshgrid(h_vals, s_vals)
X_grid = np.column_stack([H.ravel(), S.ravel()])
V_grid = model.Vtot(X_grid, Tn).reshape(H.shape)
V_plot = np.clip(V_grid, np.percentile(V_grid, 0), np.percentile(V_grid, 90))
V_shifted = V_plot - model.Vtot(np.array([[0.0, 0.0]]), Tn)

norm = Normalize(vmin=V_shifted.min(), vmax=V_shifted.max())
sm   = ScalarMappable(cmap='RdBu_r', norm=norm)

fig, ax = plt.subplots(figsize=(8.5, 6))

cp = ax.contourf(H, S, V_shifted, levels=55, cmap='RdBu_r', norm=norm)
ax.contour(H, S, V_shifted, levels=55, colors='k', linewidths=0.3, alpha=1)

#ax.plot(path_points[:, 0], path_points[:, 1], label='Tunneling path', color='w', lw=2.5, ls='-')
ax.plot(highn[0], highn[1], 'r*', markersize=15, zorder=5, markeredgecolor='k', markeredgewidth=0.5,
        label=rf'High Phase ({path_points[-1, 0]:.0f}, {path_points[-1, 1]:.0f}) GeV')
ax.plot(lown[0], lown[1], 'b*', markersize=15, zorder=5, markeredgecolor='k', markeredgewidth=0.5,
        label=rf'Low Phase ({path_points[0, 0]:.0f}, {path_points[0, 1]:.0f}) GeV')

ax.set_xlabel(r'$\varphi_h \, [\mathrm{GeV}]$', fontsize=18)
ax.set_ylabel(r'$\varphi_s \, [\mathrm{GeV}]$', fontsize=18)
ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
ax.ticklabel_format(style='sci', axis='y', scilimits=(-2, 2))
ax.yaxis.get_offset_text().set_fontsize(15)

for spine in ax.spines.values():
    spine.set_linewidth(1.5)

ax.tick_params(axis='both', which='major', direction='in',
               length=8, width=1.2, labelsize=15, top=True, right=True)
ax.tick_params(axis='both', which='minor', direction='in',
               length=4, width=1,   labelsize=15, top=True, right=True)
ax.minorticks_on()

cbar = fig.colorbar(sm, ax=ax, pad=0.01)
cbar.set_label(r'$V_\mathrm{eff}(\varphi_h,\varphi_s) \, [\mathrm{GeV^4}]$', fontsize=18)
cbar.ax.tick_params(labelsize=15)
cbar.ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
cbar.ax.yaxis.get_offset_text().set_fontsize(15)
plt.ticklabel_format(style='sci', axis='y', scilimits=(-2,3))
for spine in cbar.ax.spines.values():
    spine.set_linewidth(1.5)
cbar.ax.tick_params(axis='both', which='major', direction='in',
               length=8, width=1.2, labelsize=15)

ax.legend(fontsize=18, frameon=True, fancybox=False, loc = "upper left", bbox_to_anchor=(0.01, 0.99), 
          ncol = 1, edgecolor="black", framealpha=0.65, labelspacing=0.2, handletextpad=0.3, handlelength=1, columnspacing=1)

annotation = (rf"$T_c   = {Tc:.2f} \, \mathrm{{GeV}}$"
              "\n"rf"$T_n = {Tn:.2f} \, \mathrm{{GeV}}$"
              "\n"rf"$\xi_c = {xic:.1f}$")
ax.text(0.96, 0.05, annotation,transform=ax.transAxes,fontsize=18,verticalalignment='bottom',horizontalalignment='right',
       bbox=dict(facecolor='white', edgecolor='black', alpha=0.65))

plt.title(f"Effective Potential at {Tn:.2f} GeV", loc='left', fontsize=20, fontweight='bold')
plt.tight_layout()
plt.savefig(r"Figures\Unmix_Tn_contour.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Test Parameters

# %%
# Define the parameters
v0 = 246.22
u0 = 200.0
params = physical_to_lagrangian(
    m1    = 125.20,   # GeV  
    m2    = 60.0,    # GeV 
    theta = 0,      # rad  
    v     = v0,   # GeV
    u     = u0,     # GeV 
    lHS   = 0.15,     #     
    lS    = 0.1,      #     
)
print(params)

model = xSM(**{k: params[k] for k in ['lH','lHS','muHS','lS','mu3']},
            v=v0, u=u0)
v = model.v_os
u = model.u_os

# Find the numeric minima
res = minimize(
    lambda x: model.Vtot(np.array([[x[0], x[1]]]), 0.0).item(),
    x0=[300, 50],          
    bounds=[(0, 350), (-500, 500)],
    method='L-BFGS-B'
)
v_num, u_num = res.x

print(f"Numerical vev: ({v_num:.2f},{u_num:.2f}) GeV")
# Out:
# {'lH': 0.1292801978686813, 'lHS': 0.15, 'muHS': -30.0, 'lS': 0.1, 'mu3': 44.734108150000004, 'muH2': 4837.52, 'muS2': -4946.821630000001}
# Numerical vev: (246.22,200.00) GeV

# %% [markdown]
# ### $V_0$

# %%
# Grid in (h, s)
h_vals = np.linspace(0, 350, 200)
s_vals = np.linspace(0, 400, 200)
H, S   = np.meshgrid(h_vals, s_vals)
X_grid = np.column_stack([H.ravel(), S.ravel()])
V_grid = model.V0(X_grid).reshape(H.shape)
V_plot = np.clip(V_grid, np.percentile(V_grid, 0), np.percentile(V_grid, 100))
V_shifted = V_plot - model.V0(np.array([[0.0, 0.0]]))

norm = TwoSlopeNorm(vcenter=0, vmin=V_shifted.min(), vmax=V_shifted.max())
sm   = ScalarMappable(cmap='RdBu_r', norm=norm)

fig, ax = plt.subplots(figsize=(8.5, 6))

cp = ax.contourf(H, S, V_shifted, levels=50, cmap='RdBu_r', norm=norm)
ax.contour(H, S, V_shifted, levels=50, colors='k', linewidths=0.5, alpha=1)
ax.plot(v, u, 'w*', markersize=15, zorder=5, markeredgecolor='k', markeredgewidth=0.5,label=rf'$\langle\varphi_h, \varphi_s\rangle = ({v:.2f},\,{u:.0f})$ GeV')

ax.set_xlabel(r'$\varphi_h \, [\mathrm{GeV}]$', fontsize=18)
ax.set_ylabel(r'$\varphi_s \, [\mathrm{GeV}]$', fontsize=18)
ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
ax.ticklabel_format(style='sci', axis='y', scilimits=(-2, 2))
ax.yaxis.get_offset_text().set_fontsize(15)

for spine in ax.spines.values():
    spine.set_linewidth(1.5)

ax.tick_params(axis='both', which='major', direction='in',
               length=8, width=1.2, labelsize=15, top=True, right=True)
ax.tick_params(axis='both', which='minor', direction='in',
               length=4, width=1,   labelsize=15, top=True, right=True)
ax.minorticks_on()

cbar = fig.colorbar(sm, ax=ax, pad=0.01)
cbar.set_label(r'$V_\mathrm{eff}(\varphi_h,\varphi_s) \, [\mathrm{GeV^4}]$', fontsize=18)
cbar.ax.tick_params(labelsize=15)
cbar.ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
cbar.ax.yaxis.get_offset_text().set_fontsize(15)
plt.ticklabel_format(style='sci', axis='y', scilimits=(-2,3))
for spine in cbar.ax.spines.values():
    spine.set_linewidth(1.5)
cbar.ax.tick_params(axis='both', which='major', direction='in',
               length=8, width=1.2, labelsize=15)

ax.legend(fontsize=18, frameon=True, fancybox=False, loc = "upper left", bbox_to_anchor=(0.01, 0.99),ncol = 1, edgecolor="black", framealpha=0.9, labelspacing=0.2, handletextpad=0.3, handlelength=1, columnspacing=1)

plt.title(r"Tree Level Potential at T=0", loc='left', fontsize=20, fontweight='bold')
plt.tight_layout()
plt.savefig(r"Figures\Test_V0.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# ### $V_1$

# %%
# Grid in (h, s)
h_vals = np.linspace(0, 350, 200)
s_vals = np.linspace(0, 400, 200)
H, S   = np.meshgrid(h_vals, s_vals)
X_grid = np.column_stack([H.ravel(), S.ravel()])
V_grid = model.Vtot(X_grid, 0.0).reshape(H.shape)
V_plot = np.clip(V_grid, np.percentile(V_grid, 0), np.percentile(V_grid, 100))
V_shifted = V_plot - model.Vtot(np.array([[0.0, 0.0]]), 0.0)

norm = Normalize(vmin=V_shifted.min(), vmax=V_shifted.max()) # Normalize(vmin=V_shifted.min(), vmax=V_shifted.max())
sm   = ScalarMappable(cmap='RdBu_r', norm=norm)

fig, ax = plt.subplots(figsize=(8.5, 6))

cp = ax.contourf(H, S, V_shifted, levels=50, cmap='RdBu_r', norm=norm)
ax.contour(H, S, V_shifted, levels=50, colors='k', linewidths=0.5, alpha=1)
ax.plot(v, u, 'w*', markersize=15, zorder=5, markeredgecolor='k', markeredgewidth=0.5,label=rf'$\langle\varphi_h, \varphi_s\rangle = ({v:.2f},\,{u:.0f})$ GeV')

ax.set_xlabel(r'$\varphi_h \, [\mathrm{GeV}]$', fontsize=18)
ax.set_ylabel(r'$\varphi_s \, [\mathrm{GeV}]$', fontsize=18)
ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
ax.ticklabel_format(style='sci', axis='y', scilimits=(-2, 2))
ax.yaxis.get_offset_text().set_fontsize(15)

for spine in ax.spines.values():
    spine.set_linewidth(1.5)

ax.tick_params(axis='both', which='major', direction='in',
               length=8, width=1.2, labelsize=15, top=True, right=True)
ax.tick_params(axis='both', which='minor', direction='in',
               length=4, width=1,   labelsize=15, top=True, right=True)
ax.minorticks_on()

cbar = fig.colorbar(sm, ax=ax, pad=0.01)
cbar.set_label(r'$V_\mathrm{eff}(\varphi_h,\varphi_s) \, [\mathrm{GeV^4}]$', fontsize=18)
cbar.ax.tick_params(labelsize=15)
cbar.ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
cbar.ax.yaxis.get_offset_text().set_fontsize(15)
plt.ticklabel_format(style='sci', axis='y', scilimits=(-2,3))
for spine in cbar.ax.spines.values():
    spine.set_linewidth(1.5)
cbar.ax.tick_params(axis='both', which='major', direction='in',
               length=8, width=1.2, labelsize=15)

ax.legend(fontsize=18, frameon=True, fancybox=False, loc = "upper left", bbox_to_anchor=(0.01, 0.99),ncol = 1, edgecolor="black", framealpha=0.9, labelspacing=0.2, handletextpad=0.3, handlelength=1, columnspacing=1)

plt.title(rf"Coleman-Weinberg at T=0", loc='left', fontsize=20, fontweight='bold')
plt.tight_layout()
plt.savefig(r"Figures\Test_V1.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Phase transition

# %%
model.findAllTransitions()
print()
print("The Model has",len(model.TnTrans),"transition(s)")
# Out:
# Tracing phase starting at x = [246.21999982 199.99999893] ; t = 0.0
# Tracing minimum up
# traceMinimum t0 = 0
# ......................................................................................................................................................................................................................
# Tracing phase starting at x = [-2.05909479e-05  2.79754653e+01] ; t = 145.50092164481407
# Tracing minimum down
# traceMinimum t0 = 145.501
# ...........................
# Tracing minimum up
# traceMinimum t0 = 145.501
# .............................................................................................................................................................................................
# Tunneling from phase 1 to phase 0 at T=137.8713
# high_vev = [4.70187065e-04 2.50993366e+01]
# low_vev = [149.82768366 184.2328176 ]
# Path deformation converged. 48 steps. fRatio = 1.83489e-02
# Path deformation converged. 16 steps. fRatio = 1.34805e-02
# Path deformation converged. 6 steps. fRatio = 1.10054e-02
# Path deformation converged. 1 steps. fRatio = 1.04718e-03
# Tunneling from phase 1 to phase 0 at T=137.8718
# high_vev = [-3.14997760e-06  2.50995069e+01]
# low_vev = [149.82618472 184.23219272]
# Path deformation converged. 48 steps. fRatio = 1.83783e-02
# Path deformation converged. 16 steps. fRatio = 1.34245e-02
# Path deformation converged. 6 steps. fRatio = 1.11222e-02
# Path deformation converged. 1 steps. fRatio = 1.01543e-03
# Tunneling from phase 1 to phase 0 at T=137.8723
# high_vev = [3.33974219e-05 2.50996978e+01]
# low_vev = [149.82468059 184.23157669]
# Path deformation converged. 48 steps. fRatio = 1.83812e-02
# Path deformation converged. 16 steps. fRatio = 1.33715e-02
# Path deformation converged. 6 steps. fRatio = 1.12177e-02
# Path deformation converged. 1 steps. fRatio = 1.04576e-03
# Tunneling from phase 1 to phase 0 at T=139.5291
# high_vev = [6.12329759e-05 2.56933214e+01]
# low_vev = [144.66214991 181.85735471]
# Path deformation converged. 44 steps. fRatio = 1.91411e-02
# Path deformation converged. 8 steps. fRatio = 1.14404e-02
# Path deformation converged. 1 steps. fRatio = 7.94117e-02
# Tunneling from phase 1 to phase 0 at T=138.3715
# high_vev = [-3.88569894e-05  2.52767000e+01]
# low_vev = [148.31192661 183.58566599]
# Path deformation converged. 46 steps. fRatio = 1.53945e-02
# Path deformation converged. 13 steps. fRatio = 1.36707e-02
# Path deformation converged. 8 steps. fRatio = 7.75316e-03
# Path deformation converged. 1 steps. fRatio = 8.27799e-03
# Tunneling from phase 1 to phase 0 at T=139.1299
# high_vev = [3.82505474e-06 2.55486844e+01]
# low_vev = [145.94453967 182.49460727]
# Path deformation converged. 46 steps. fRatio = 1.77660e-02
# Path deformation converged. 10 steps. fRatio = 1.98784e-02
# Path deformation converged. 7 steps. fRatio = 1.12008e-02
# Path deformation converged. 1 steps. fRatio = 4.42473e-03
# Tunneling from phase 1 to phase 0 at T=138.7353
# high_vev = [-4.65603166e-05  2.54066896e+01]
# low_vev = [147.18724581 183.08031292]
# Path deformation converged. 44 steps. fRatio = 1.96820e-02
# Path deformation converged. 12 steps. fRatio = 1.36137e-02
# Path deformation converged. 8 steps. fRatio = 5.01896e-03
# Path deformation converged. 1 steps. fRatio = 3.41842e-03
# Tunneling from phase 1 to phase 0 at T=138.8068
# high_vev = [2.89285647e-05 2.54323682e+01]
# low_vev = [146.96377658 182.97715897]
# Path deformation converged. 44 steps. fRatio = 1.98114e-02
# Path deformation converged. 12 steps. fRatio = 1.11928e-02
# Path deformation converged. 7 steps. fRatio = 1.76792e-02
# Path deformation converged. 1 steps. fRatio = 6.93280e-03
# Tunneling from phase 1 to phase 0 at T=138.8063
# high_vev = [6.26118927e-05 2.54321813e+01]
# low_vev = [146.96533668 182.97788913]
# Path deformation converged. 44 steps. fRatio = 1.97918e-02
# Path deformation converged. 12 steps. fRatio = 1.12079e-02
# Path deformation converged. 7 steps. fRatio = 1.77010e-02
# Path deformation converged. 1 steps. fRatio = 7.08715e-03
#
# The Model has 1 transition(s)

# %%
Trans = model.TnTrans[0]

Tc    = Trans['crit_trans']['Tcrit']
highc = Trans['crit_trans']['high_vev']
lowc  = Trans['crit_trans']['low_vev']
xic   = abs(lowc[0] - highc[0]) / Tc
Tn    = Trans['Tnuc']
highn = Trans['high_vev']
lown  = Trans['low_vev']
xin   = abs(lown[0] - highn[0]) / Tc

print(xic)
# Out:
# 0.9941263174493806

# %%
T = Tc

# Grid in (h, s)
h_vals = np.linspace(-10, 160, 200)
s_vals = np.linspace(0, 220, 200)
H, S   = np.meshgrid(h_vals, s_vals)
X_grid = np.column_stack([H.ravel(), S.ravel()])
V_grid = model.Vtot(X_grid, T).reshape(H.shape)
V_plot = np.clip(V_grid, np.percentile(V_grid, 0), np.percentile(V_grid, 98))
V_shifted = V_plot - model.Vtot(np.array([[0.0, 0.0]]), T)

norm = Normalize(vmin=V_shifted.min(), vmax=V_shifted.max()) # Normalize(vmin=V_shifted.min(), vmax=V_shifted.max())
sm   = ScalarMappable(cmap='RdBu_r', norm=norm)

fig, ax = plt.subplots(figsize=(8.5, 6))

cp = ax.contourf(H, S, V_shifted, levels=50, cmap='RdBu_r', norm=norm)
ax.contour(H, S, V_shifted, levels=50, colors='k', linewidths=0.5, alpha=1)
ax.plot(highc[0], highc[1], 'r*', markersize=15, zorder=5, markeredgecolor='k', markeredgewidth=0.5,label=rf'High Phase: $({highc[0]:.0f},\,{highc[1]:.0f})$ GeV')
ax.plot(lowc[0], lowc[1], 'b*', markersize=15, zorder=5, markeredgecolor='k', markeredgewidth=0.5,label=rf'High Phase: $({lowc[0]:.0f},\,{lowc[1]:.0f})$ GeV')

ax.set_xlabel(r'$\varphi_h \, [\mathrm{GeV}]$', fontsize=18)
ax.set_ylabel(r'$\varphi_s \, [\mathrm{GeV}]$', fontsize=18)
ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
ax.ticklabel_format(style='sci', axis='y', scilimits=(-2, 2))
ax.yaxis.get_offset_text().set_fontsize(15)

for spine in ax.spines.values():
    spine.set_linewidth(1.5)

ax.tick_params(axis='both', which='major', direction='in',
               length=8, width=1.2, labelsize=15, top=True, right=True)
ax.tick_params(axis='both', which='minor', direction='in',
               length=4, width=1,   labelsize=15, top=True, right=True)
ax.minorticks_on()

cbar = fig.colorbar(sm, ax=ax, pad=0.01)
cbar.set_label(r'$V_\mathrm{eff}(\varphi_h,\varphi_s) \, [\mathrm{GeV^4}]$', fontsize=18)
cbar.ax.tick_params(labelsize=15)
cbar.ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
cbar.ax.yaxis.get_offset_text().set_fontsize(15)
plt.ticklabel_format(style='sci', axis='y', scilimits=(-2,3))
for spine in cbar.ax.spines.values():
    spine.set_linewidth(1.5)
cbar.ax.tick_params(axis='both', which='major', direction='in',
               length=8, width=1.2, labelsize=15)

ax.legend(fontsize=18, frameon=True, fancybox=False, loc = "upper left", bbox_to_anchor=(0.01, 0.99),ncol = 1, edgecolor="black", framealpha=0.65, labelspacing=0.2, handletextpad=0.3, handlelength=1, columnspacing=1)

annotation = (rf"$T_c   = {Tc:.2f} \, \mathrm{{GeV}}$"
              "\n"rf"$T_n = {Tn:.2f} \, \mathrm{{GeV}}$"
              "\n"rf"$\xi_c = {xic:.1f}$")
ax.text(0.96, 0.05, annotation,transform=ax.transAxes,fontsize=18,verticalalignment='bottom',horizontalalignment='right',
       bbox=dict(facecolor='white', edgecolor='black', alpha=0.65))

plt.title(rf"Coleman-Weinberg at T={T:.2f}", loc='left', fontsize=20, fontweight='bold')
plt.tight_layout()
plt.savefig(r"Figures\Test_V1_Tc.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# # Parameter Scan

# %%
def physical_to_lagrangian(m1, m2, theta, v, u, lHS, lS):
    """
    Convert physical parameters to xSM Lagrangian parameters.

    Inputs
    ------
    m1, m2  : scalar mass eigenvalues (GeV), m1 < m2 convention
    theta   : mixing angle (rad)
    v, u    : Higgs and singlet vevs (GeV)
    lHS     : quartic portal lambda_HS
    lS      : singlet quartic lambda_S

    Outputs
    -------
    dict with keys: lH, muHS, mu3, muH2, muS2
    (lHS and lS are inputs, returned unchanged for completeness)
    """
    ct = np.cos(theta)
    st = np.sin(theta)
    
    Mhh = m1**2 * ct**2 + m2**2 * st**2
    Mss = m1**2 * st**2 + m2**2 * ct**2
    Mhs = (m1**2 - m2**2) * ct * st
    
    lH   = Mhh / (2.0 * v**2)

    muHS = Mhs / v  -  lHS * u

    # Relations don't hold if u=0
    if abs(u) > 1e-6:
        mu3 = (2.0*lS*u**2  -  Mss  -  muHS*v**2/(2.0*u)) / u
    else:
        mu3 = 0.0   

    # Mass parameters from tadpole conditions
    muH2 = lH*v**2  +  0.5*lHS*u**2  +  muHS*u
    if abs(u) > 1e-6:
        muS2 = 0.5*lHS*v**2  +  muHS*v**2/(2.0*u)  +  lS*u**2  -  mu3*u
    else:
        muS2 = 0.0

    return dict(lH=lH, lHS=lHS, muHS=muHS, lS=lS, mu3=mu3, muH2=muH2, muS2=muS2)

# %%
# Define the parameters
v0 = 246.22
u0 = 300.0
params = physical_to_lagrangian(
    m1    = 125.20,   # GeV  
    m2    = 60.0,    # GeV 
    theta = 0.001,      # rad  
    v     = v0,   # GeV
    u     = u0,     # GeV 
    lHS   = 0.05,     #     
    lS    = 0.05,      #     
)
print(params)

model = xSM(**{k: params[k] for k in ['lH','lHS','muHS','lS','mu3']},
            v=v0, u=u0)
v = model.v_os
u = model.u_os

# Find the numeric minima
res = minimize(
    lambda x: model.Vtot(np.array([[x[0], x[1]]]), 0.0).item(),
    x0=[300, 50],          
    bounds=[(0, 350), (-1000, 1000)],
    method='L-BFGS-B'
)
v_num, u_num = res.x

Deltav = (v0-v_num)/v0
Deltau = (u0-u_num)/u0
print(f"Stability Check: ({Deltav:.1f},{Deltau:.1f}) GeV")
# Out:
# {'lH': 0.12928009827958678, 'lHS': 0.05, 'muHS': -14.950958362643266, 'lS': 0.05, 'mu3': 23.03546648117607, 'muH2': 5602.226453689032, 'muS2': -2405.684753741616}
# Stability Check: (-0.0,0.0) GeV

# %%
model.Tmax = 200
trans = model.calcTcTrans()
Tc   = trans[0]['Tcrit']
high = trans[0]['high_vev']
low  = trans[0]['low_vev']
xi_c = abs(low[0] - high[0]) / Tc
print(f"Tc = {Tc:.2f} GeV  |  xi_c = {xi_c:.2f}")
# Out:
# Tracing phase starting at x = [246.21999918 299.99999908] ; t = 0.0
# Tracing minimum up
# traceMinimum t0 = 0
# ....................................................................................................................................................................................................................................................................
# Tracing phase starting at x = [-3.76812191e-06  3.26757268e+01] ; t = 155.8998270300597
# Tracing minimum down
# traceMinimum t0 = 155.9
# .........................................
# Tracing minimum up
# traceMinimum t0 = 155.9
# ...........................
# Tracing phase starting at x = [-4.44714183e-05  1.94082519e+01] ; t = 121.03841284558102
# Tracing minimum down
# traceMinimum t0 = 121.038
# .................................
# Tracing minimum up
# traceMinimum t0 = 121.038
# ..........................................
# Tc = 137.66 GeV  |  xi_c = 1.10

# %%
# Grid in (h, s)
h_vals = np.linspace(0, 300, 200)
s_vals = np.linspace(0, 400, 200)
H, S   = np.meshgrid(h_vals, s_vals)
X_grid = np.column_stack([H.ravel(), S.ravel()])
V_grid = model.Vtot(X_grid,0).reshape(H.shape)
V_plot = np.clip(V_grid, np.percentile(V_grid, 0), np.percentile(V_grid, 99))
V_shifted = V_plot - model.Vtot(np.array([[0.0, 0.0]]),0)

norm = TwoSlopeNorm(vcenter=0, vmin=V_shifted.min(), vmax=V_shifted.max())
sm   = ScalarMappable(cmap='RdBu_r', norm=norm)

fig, ax = plt.subplots(figsize=(8.5, 6))

cp = ax.contourf(H, S, V_shifted, levels=50, cmap='RdBu_r', norm=norm)
ax.contour(H, S, V_shifted, levels=50, colors='k', linewidths=0.5, alpha=1)
ax.plot(v, u, 'w*', markersize=15, zorder=5, markeredgecolor='k', markeredgewidth=0.5,label=rf'$\langle\varphi_h, \varphi_s\rangle = ({v:.2f},\,{u:.0f})$ GeV')

ax.set_xlabel(r'$\varphi_h \, [\mathrm{GeV}]$', fontsize=18)
ax.set_ylabel(r'$\varphi_s \, [\mathrm{GeV}]$', fontsize=18)
ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
ax.ticklabel_format(style='sci', axis='y', scilimits=(-2, 2))
ax.yaxis.get_offset_text().set_fontsize(15)

for spine in ax.spines.values():
    spine.set_linewidth(1.5)

ax.tick_params(axis='both', which='major', direction='in',
               length=8, width=1.2, labelsize=15, top=True, right=True)
ax.tick_params(axis='both', which='minor', direction='in',
               length=4, width=1,   labelsize=15, top=True, right=True)
ax.minorticks_on()

cbar = fig.colorbar(sm, ax=ax, pad=0.01)
cbar.set_label(r'$V_\mathrm{eff}(\varphi_h,\varphi_s) \, [\mathrm{GeV^4}]$', fontsize=18)
cbar.ax.tick_params(labelsize=15)
cbar.ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
cbar.ax.yaxis.get_offset_text().set_fontsize(15)
plt.ticklabel_format(style='sci', axis='y', scilimits=(-2,3))
for spine in cbar.ax.spines.values():
    spine.set_linewidth(1.5)
cbar.ax.tick_params(axis='both', which='major', direction='in',
               length=8, width=1.2, labelsize=15)

ax.legend(fontsize=18, frameon=True, fancybox=False, loc = "lower left", bbox_to_anchor=(0.01, 0.01),ncol = 1, edgecolor="black", framealpha=0.9, labelspacing=0.2, handletextpad=0.3, handlelength=1, columnspacing=1)

plt.title(r"Effective Potential at T=0", loc='left', fontsize=20, fontweight='bold')
plt.tight_layout()
plt.savefig(r"Figures\Scan_VCW.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
# Grid in (h, s)
h_vals = np.linspace(-10, 170, 500)
s_vals = np.linspace(0, 350, 500)
H, S   = np.meshgrid(h_vals, s_vals)
X_grid = np.column_stack([H.ravel(), S.ravel()])
V_grid = model.Vtot(X_grid,Tc).reshape(H.shape)
V_plot = np.clip(V_grid, np.percentile(V_grid, 0), np.percentile(V_grid, 95))
V_shifted = V_plot - model.Vtot(np.array([[0.0, 0.0]]),Tc)

norm = Normalize(vmin=V_shifted.min(), vmax=V_shifted.max())
sm   = ScalarMappable(cmap='RdBu_r', norm=norm)

fig, ax = plt.subplots(figsize=(8.5, 6))

cp = ax.contourf(H, S, V_shifted, levels=50, cmap='RdBu_r', norm=norm)
ax.contour(H, S, V_shifted, levels=50, colors='k', linewidths=0.5, alpha=1)
ax.plot(high[0], high[1], 'r*', markersize=15, zorder=5, markeredgecolor='k', markeredgewidth=0.5,label=rf'High Phase: $({high[0]:.0f},\,{high[1]:.0f})$ GeV')
ax.plot(low[0], low[1], 'b*', markersize=15, zorder=5, markeredgecolor='k', markeredgewidth=0.5,label=rf'High Phase: $({low[0]:.0f},\,{low[1]:.0f})$ GeV')

ax.set_xlabel(r'$\varphi_h \, [\mathrm{GeV}]$', fontsize=18)
ax.set_ylabel(r'$\varphi_s \, [\mathrm{GeV}]$', fontsize=18)
ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
ax.ticklabel_format(style='sci', axis='y', scilimits=(-2, 2))
ax.yaxis.get_offset_text().set_fontsize(15)

for spine in ax.spines.values():
    spine.set_linewidth(1.5)

ax.tick_params(axis='both', which='major', direction='in',
               length=8, width=1.2, labelsize=15, top=True, right=True)
ax.tick_params(axis='both', which='minor', direction='in',
               length=4, width=1,   labelsize=15, top=True, right=True)
ax.minorticks_on()

cbar = fig.colorbar(sm, ax=ax, pad=0.01)
cbar.set_label(r'$V_\mathrm{eff}(\varphi_h,\varphi_s,T) \, [\mathrm{GeV^4}]$', fontsize=18)
cbar.ax.tick_params(labelsize=15)
cbar.ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
cbar.ax.yaxis.get_offset_text().set_fontsize(15)
plt.ticklabel_format(style='sci', axis='y', scilimits=(-2,3))
for spine in cbar.ax.spines.values():
    spine.set_linewidth(1.5)
cbar.ax.tick_params(axis='both', which='major', direction='in',
               length=8, width=1.2, labelsize=15)

ax.legend(fontsize=18, frameon=True, fancybox=False, loc = "lower right", bbox_to_anchor=(0.99, 0.01),ncol = 1, edgecolor="black", framealpha=0.9, labelspacing=0.2, handletextpad=0.3, handlelength=1, columnspacing=1)

plt.title(rf"Effective Potential at T={Tc:.2f} GeV", loc='left', fontsize=20, fontweight='bold')
plt.tight_layout()
plt.savefig(r"Figures\Scan_TC.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Functions and Dictionaries
